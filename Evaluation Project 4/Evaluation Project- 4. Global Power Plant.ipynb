# %% [markdown]
# >## <b> Evaluation Project 4:Global Power Plant </b>
# <b><em> By: Ms. Yashshree bawiskar </em></b>
#
# <b><em> Batch: 1838 </em></b>

# %% [markdown]
# **Global Power Plant Database**
# **Problem Statement:**
#
# **Description**
#
# The Global Power Plant Database is a comprehensive, open source database of power plants around the world. It centralizes power plant data to make it easier to navigate, compare and draw insights for one’s own analysis. The database covers approximately 35,000 power plants from 167 countries and includes thermal plants (e.g. coal, gas, oil, nuclear, biomass, waste, geothermal) and renewables (e.g. hydro, wind, solar). Each power plant is geolocated and entries contain information on plant capacity, generation, ownership, and fuel type. It will be continuously updated as data becomes available.
#
#
# Prediction :   Make two prediction  1) Primary Fuel    2) capacity_mw
#
# **Find the dataset link below.**
#
# Downlaod Files:
# https://github.com/wri/global-power-plant-database/blob/master/source_databases_csv/database_IND.csv

# %% [markdown]
# __Importing required liabaries__

# %%
import pandas as pd # for data wrangling purpose
import numpy as np # Basic computation library
import seaborn as sns # For Visualization 
import matplotlib.pyplot as plt # ploting package
# %matplotlib inline
import warnings # Filtering warnings
warnings.filterwarnings('ignore')

# %%
# Importing CSV File
df=pd.read_csv('database_IND.csv')

# %%
print('No of Rows:',df.shape[0])
print('No of Columns:',df.shape[1])
df.head()
# Out:
# No of Rows: 907
# No of Columns: 27
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# 0                    NaN                  NaN                 NaN
# 1                    NaN                  NaN                 NaN
# 2                    NaN                  NaN                 NaN
# 3                 2019.0                  NaN          617.789264
# 4                 2019.0                  NaN         3035.550000
#
#   generation_gwh_2015 generation_gwh_2016 generation_gwh_2017  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                 NaN                 NaN                 NaN
# 3             843.747          886.004428          663.774500
# 4            5916.370         6243.000000         5385.579736
#
#    generation_gwh_2018  generation_gwh_2019         generation_data_source  \
# 0                  NaN                  NaN                            NaN
# 1                  NaN                  NaN                            NaN
# 2                  NaN                  NaN                            NaN
# 3           626.239128                  NaN  Central Electricity Authority
# 4          7279.000000                  NaN  Central Electricity Authority
#
#    estimated_generation_gwh
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ## In primary observation we have a dataset which having 907 no. of rows and 27 no. of columns.
# ##  In the given data set many features has NaN value. We will check in further data investingation which features has NaN value and we will do pre processing accordingly.

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %% [markdown]
# **Data description:**
#
# - country :- 3 character country code corresponding to the ISO 3166-1 alpha-3 specification.
# - country_long :- longer form of the country designation.
# - name :- name or title of the power plant, generally in Romanized form.
# - gppd_idnr :- 10 or 12 character identifier for the power plant.
# - capacity_mw :- electrical generating capacity in megawatts.
# - latitude :- geolocation in decimal degrees; WGS84 (EPSG:4326).
# - longitude :- geolocation in decimal degrees; WGS84 (EPSG:4326).
# - primary_fuel :- energy source used in primary electricity generation or export.
# - other_fuel1 :- energy source used in electricity generation or export.
# - other_fuel2 :- energy source used in electricity generation or export.
# - other_fuel3 :- energy source used in electricity generation or export.
# - commissioning_year :- year of plant operation, weighted by unit-capacity when data is available.
# - owner :- majority shareholder of the power plant, generally in Romanized form.
# - source :- entity reporting the data; could be an organization, report, or document, generally in Romanized form.
# - url :- web document corresponding to the source field.
# - geolocation_source :- attribution for geolocation information.
# - wepp_id :- a reference to a unique plant identifier in the widely-used PLATTS-WEPP database.
# - year_of_capacity_data :- year the capacity information was reported.
# - generation_gwh_2013 :- electricity generation in gigawatt-hours reported for the year 2013.
# - generation_gwh_2014 :- electricity generation in gigawatt-hours reported for the year 2014.
# - generation_gwh_2015 :- electricity generation in gigawatt-hours reported for the year 2015.
# - generation_gwh_2016 :- electricity generation in gigawatt-hours reported for the year 2016.
# - generation_gwh_2017 :- electricity generation in gigawatt-hours reported for the year 2017.
# - generation_data_source :- attribution for the reported generation information.
# - estimated_generation_gwh :- estimated annual electricity generation in gigawatt-hours.

# %% [markdown]
# ## As we see problem statement we need to predict two features:
#
# **1. Primary Fuel**
#
# **2. Capacity_mw**
#
#
# In Primafacia while viewing  our target features we can get inferece and we need to apply classification and Regression model for it.
#
# ### 1. Primary Fuel : As we seen the data set , its contain categorical data, so we can easly say that here we need to apply classification.
#
# ### 2. Capacity_mw: As we seen the dataset , this feature contain a contionous data, so we need to apply regression model.

# %% [markdown]
# ## Now We will do Data Wrangling

# %%
df.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_gwh_2018         float64
# generation_gwh_2019         float64
# generation_data_source       object
# estimated_generation_gwh    float64
# dtype: object

# %% [markdown]
# ### - Here we have mainly two types of data one is object type and second is float type.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
#  13  source                    907 non-null    object
#  14  url                       907 non-null    object
#  15  geolocation_source        888 non-null    object
#  16  wepp_id                   0 non-null      float64
#  17  year_of_capacity_data     519 non-null    float64
#  18  generation_gwh_2013       0 non-null      float64
#  19  generation_gwh_2014       398 non-null    float64
#  20  generation_gwh_2015       422 non-null    float64
#  21  generation_gwh_2016       434 non-null    float64
#  22  generation_gwh_2017       440 non-null    float64
#  23  generation_gwh_2018       448 non-null    float64
#  24  generation_gwh_2019       0 non-null      float64
#  25  generation_data_source    449 non-null    object
#  26  estimated_generation_gwh  0 non-null      float64
# dtypes: float64(15), object(12)
# memory usage: 191.4+ KB

# %% [markdown]
# ####   Observation :
# #### - Dataset contain 908 rows with 25 columns.
# #### - other_fuel3,estimated_generation_gwh,wepp_id,other_fuel2 are empty columns.

# %% [markdown]
# ## Now we will check data integrity

# %%
df.isin([' ','NA','-','?']).sum().any()
# Out:
# False

# %% [markdown]
# - No whitespace, NA, '-' exist in dataset.

# %% [markdown]
# __Since dataset is large, Let's check for any entry which is repeated or duplicated in dataset.__

# %%
df.duplicated().sum() # This will check if any duplicate entry or duplicate row with same value exist
# Out:
# 0

# %% [markdown]
# Here no duplicated value avaialble in the dataset

# %% [markdown]
# <b><em> No Duplicate Entry Present in data.
#
# If we Check CSV file and look at dataset head, there are lot of data cleaning operation need to done before performing any EDA and ML modelling.At first sight we can come across following observation in CSV file:
#
# - Lot of missing data in certain columns.
# - Lot of  Non relevant data like gppd_idnr,url.
# - and many more.
#
# At end data need to clean and we will try to do some feature engineering afterwards to modify some columns.</em></b>
#
#
# ### Start with looking at missing value.

# %% [markdown]
# <b> Before checking null value and missing value imputation , first remove empty columns and non relevalent columns.
#
# Columns we are going remove are :
#
# - estimated_generation_gwh - Empty
# - wepp_id - Empty
# - other_fuel2 - 98% data missing
# - other_fuel3 - Empty
# - owner - More than 60 % data missing
# - year_of_capacity_data - Missing data with single unique value
# - country - non relevalent info
# - country_long - non relevalent info
# - gppd_idnr -non relevalent info
# - url - No missing value but of no use
# </b>

# %%
df.drop(columns=["country","country_long",'url','year_of_capacity_data',
                 'gppd_idnr','owner','other_fuel3','other_fuel2',
                 'estimated_generation_gwh','wepp_id'],axis=1,inplace=True)

# %%
#Finding what percentage of data is missing from the dataset
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                         Missing Values  % Missing data
# generation_gwh_2019                907      100.000000
# generation_gwh_2013                907      100.000000
# other_fuel1                        709       78.169791
# generation_gwh_2014                509       56.119074
# generation_gwh_2015                485       53.472988
# generation_gwh_2016                473       52.149945
# generation_gwh_2017                467       51.488423
# generation_gwh_2018                459       50.606395
# generation_data_source             458       50.496141
# commissioning_year                 380       41.896362
# latitude                            46        5.071665
# longitude                           46        5.071665
# geolocation_source                  19        2.094818
# capacity_mw                          0        0.000000
# source                               0        0.000000
# primary_fuel                         0        0.000000
# name                                 0        0.000000

# %% [markdown]
# ### Here  we can see that following features have the 100% missing data, so, we can drop these features in further steps.
# - generarion_gwh_2019
# - generation _gwh_2013
#
# ### here we can see that following features have  50% or more  data is missing, we will treat them in further investivagation.
#
# - generation_gwh_2014
# - generation_gwh_2015
# - generation_gwh_2017
# - generation_gwh_2018
# - generation_data_source
# - other_fuel1

# %% [markdown]
# ## here we can see that following features having 5% or below data missing
#
# - latitude
# - longitude
# - geolocation_source

# %% [markdown]
# #### Proposed Strategy to Handle Missing data :
#
# - As Geolocation source is categorical data we can impute it with mode of category.
# - longitude and latitude can be impute with mean or median of longitude and latitude. This imputation will not distrub statstical balance of data as mean will be same at the end.
# - As commissioning year for most of industrial powerplant is missing(40%) after checking correlation we will decide to keep or drop this features.
# - In generation_data_source 50% data is missing and it doesnot have any importance in our analysis. So it is better to drop this feature.
# - There are 7 Different columns of GenerationGW-Hours for year 2013 to 2017. Its dive into it further
#     - It is important feature in for coal and hydro powerplant.
#     - It is natural to have missing data in this category. As Oil,Gas based Powerplant operated in intermitant periodic way and some renewable powerplant like wind,tide are operated seasonaly.
#     - Some new powerplant commission between 2013 and 2019. For these powerplant some data will definitely available.
#     - We cannot do any mean or median imputation here as different powerplant have different generation capacity & Generation per year depend on runtime of powerplant.
#     - We all know old powerplant normally kept off unless more demand of generation required. Reason to kept is low efficiency & high operating cost.
#     - We can neglect real value data for such important feature. We will keep this feature along with missing value and perform further investigation.
# - Other_fuel1 is another feature of some importance with missing value. Lets dive into it :
#     - Not every powerplant build to work with alternate fuel.
#     - Idea of other fuel is totally irrelevant to renewable energy source based powerplant like solar,wind,hydro.
#     - First talk about powerplant for which concept of other fuel is applicable. We can impute them based domain knowledge.
#         - Alternate Fuel of Coal based powerplant mostly is Oil or cogeneration.
#         - Alternate Fuel of Industrial Oil based powerplant is Gas.
#         - Alternate Fuel of Industrial Gas based powerplant is Oil.
#         - We cannot define any alternative fuel for nuclear powerplant as it sole based on plant design & so many option.
#     - For Renewable energy source based powerplant no alternate fuel needed. As it is categorical feature we can impute these powerplant with "Not Applicable". At end we are going Encoding these labels, 'Not Applicable' will be just one other additional label in encoding. Making no alternation on final result.

# %% [markdown]
# ## Missing value Impuatation

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
sns.boxplot( y='longitude', data=df,color='cyan')
plt.ylabel('longitude',fontsize=15)
plt.subplot(1,2,2)
sns.distplot(df['longitude'], color='b')
plt.xlabel('longitude',fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# Based on presense of outliers we will impute longitude with median.

# %%
plt.figure(figsize=(14,6))
plt.subplot(1,2,1)
sns.boxplot( y='latitude', data=df,color='cyan')
plt.ylabel('latitude',fontsize=15)
plt.subplot(1,2,2)
sns.distplot(df['latitude'], color='b')
plt.xlabel('latitude',fontsize=15)
plt.tight_layout()
plt.show()

# %%
# Missing Value Imputation of geolocation with mode
df['geolocation_source'] = df['geolocation_source'].fillna(df['geolocation_source'].mode()[0])
# Missing Value Imputation of longitude with median
df['longitude'] = df['longitude'].fillna(df['longitude'].median())
# Missing Value Imputation of latitude with mean
df['latitude'] = df['latitude'].fillna(df['latitude'].mean())

# %%
#Finding what percentage of data is missing from the dataset
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                         Missing Values  % Missing data
# generation_gwh_2019                907      100.000000
# generation_gwh_2013                907      100.000000
# other_fuel1                        709       78.169791
# generation_gwh_2014                509       56.119074
# generation_gwh_2015                485       53.472988
# generation_gwh_2016                473       52.149945
# generation_gwh_2017                467       51.488423
# generation_gwh_2018                459       50.606395
# generation_data_source             458       50.496141
# commissioning_year                 380       41.896362
# name                                 0        0.000000
# capacity_mw                          0        0.000000
# source                               0        0.000000
# primary_fuel                         0        0.000000
# longitude                            0        0.000000
# latitude                             0        0.000000
# geolocation_source                   0        0.000000

# %% [markdown]
# Based on absense of outliers we will impute latitude with mean

# %% [markdown]
# ## Now let's see the missing values in using heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull())
plt.title("Missing Values")
plt.show()

# %% [markdown]
# ## statistical Analysis

# %%
df.describe()
# Out:
#        capacity_mw    latitude   longitude  commissioning_year  \
# count   907.000000  907.000000  907.000000          527.000000
# mean    326.223755   21.197918   77.427103         1997.091082
# std     590.085456    6.079148    4.815073           17.082868
# min       0.000000    8.168900   68.644700         1927.000000
# 25%      16.725000   17.072000   74.388900         1988.000000
# 50%      59.200000   21.281800   76.719500         2001.000000
# 75%     385.250000   25.176450   79.206100         2012.000000
# max    4760.000000   34.649000   95.408000         2018.000000
#
#        generation_gwh_2013  generation_gwh_2014  generation_gwh_2015  \
# count                  0.0           398.000000           422.000000
# mean                   NaN          2431.823590          2428.226946
# std                    NaN          4026.440035          4194.596959
# min                    NaN             0.000000             0.000000
# 25%                    NaN           223.557672           176.381063
# 50%                    NaN           801.123775           711.181225
# 75%                    NaN          3035.306250          3084.121250
# max                    NaN         28127.000000         30539.000000
#
#        generation_gwh_2016  generation_gwh_2017  generation_gwh_2018  \
# count           434.000000           440.000000           448.000000
# mean           2467.936859          2547.759305          2600.804099
# std            4162.884308          4196.991169          4314.880456
# min               0.000000             0.000000             0.000000
# 25%             188.285252           177.874930           193.378250
# 50%             737.205450           817.977250           751.644375
# 75%            3282.861313          3275.690475          3143.535900
# max           30015.000000         35116.000000         35136.000000
#
#        generation_gwh_2019
# count                  0.0
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN

# %%
df.describe().T
# Out:
#                      count         mean          std        min          25%  \
# capacity_mw          907.0   326.223755   590.085456     0.0000    16.725000
# latitude             907.0    21.197918     6.079148     8.1689    17.072000
# longitude            907.0    77.427103     4.815073    68.6447    74.388900
# commissioning_year   527.0  1997.091082    17.082868  1927.0000  1988.000000
# generation_gwh_2013    0.0          NaN          NaN        NaN          NaN
# generation_gwh_2014  398.0  2431.823590  4026.440035     0.0000   223.557672
# generation_gwh_2015  422.0  2428.226946  4194.596959     0.0000   176.381063
# generation_gwh_2016  434.0  2467.936859  4162.884308     0.0000   188.285252
# generation_gwh_2017  440.0  2547.759305  4196.991169     0.0000   177.874930
# generation_gwh_2018  448.0  2600.804099  4314.880456     0.0000   193.378250
# generation_gwh_2019    0.0          NaN          NaN        NaN          NaN
#
#                              50%          75%        max
# capacity_mw            59.200000   385.250000   4760.000
# latitude               21.281800    25.176450     34.649
# longitude              76.719500    79.206100     95.408
# commissioning_year   2001.000000  2012.000000   2018.000
# generation_gwh_2013          NaN          NaN        NaN
# generation_gwh_2014   801.123775  3035.306250  28127.000
# generation_gwh_2015   711.181225  3084.121250  30539.000
# generation_gwh_2016   737.205450  3282.861313  30015.000
# generation_gwh_2017   817.977250  3275.690475  35116.000
# generation_gwh_2018   751.644375  3143.535900  35136.000
# generation_gwh_2019          NaN          NaN        NaN

# %% [markdown]
# #### Observation:
# - Bigest Powerplant has power generation capacity of 4760 MW.
# - In each Generation-GWHours columns Mean is greater than Median.
# - Powerplants are located in latitude range of 8.1689 to 34.6490 while longitudal range is 68.64 to 95.4080.
# - Oldest powerplant commission date back to 1927 and most recent powerplant is build in 2018. We will check in which timeframe most of powerplants are commission.
# - Median of capacity MW is 59.20 MW. This suggest that there are lot of small capacity powerplant in dataset.

# %%
df.describe(include=['O'])
# Out:
#                     name primary_fuel other_fuel1  \
# count                907          907         198
# unique               907            8           3
# top     GRACE INDUSTRIES         Coal         Oil
# freq                   1          258         195
#
#                                source geolocation_source  \
# count                             907                907
# unique                            191                  3
# top     Central Electricity Authority                WRI
# freq                              519                784
#
#                generation_data_source
# count                             449
# unique                              1
# top     Central Electricity Authority
# freq                              449

# %%
df.shape
# Out:
# (907, 17)

# %%
df.drop(columns=['generation_gwh_2019','generation_gwh_2013'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                        name  capacity_mw  latitude  longitude primary_fuel  \
# 0          ACME Solar Tower          2.5   28.1839    73.2407        Solar
# 1       ADITYA CEMENT WORKS         98.0   24.7663    74.6090         Coal
# 2  AES Saurashtra Windfarms         39.2   21.9038    69.3732         Wind
# 3               AGARTALA GT        135.0   23.8712    91.3602          Gas
# 4              AKALTARA TPP       1800.0   21.9603    82.4091         Coal
#
#   other_fuel1  commissioning_year                                source  \
# 0         NaN              2011.0  National Renewable Energy Laboratory
# 1         NaN                 NaN                  Ultratech Cement ltd
# 2         NaN                 NaN                                   CDM
# 3         NaN              2004.0         Central Electricity Authority
# 4         Oil              2015.0         Central Electricity Authority
#
#                      geolocation_source  generation_gwh_2014  \
# 0  National Renewable Energy Laboratory                  NaN
# 1                                   WRI                  NaN
# 2                                   WRI                  NaN
# 3                                   WRI           617.789264
# 4                                   WRI          3035.550000
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
# 2                  NaN                  NaN                  NaN
# 3              843.747           886.004428           663.774500
# 4             5916.370          6243.000000          5385.579736
#
#    generation_gwh_2018         generation_data_source
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3           626.239128  Central Electricity Authority
# 4          7279.000000  Central Electricity Authority

# %%
df.drop(columns=['generation_data_source','name'],axis=1,inplace=True)

# %%
## after dropping unwanted columns here we will check data size and missing value once again

# %%
df.shape
# Out:
# (907, 13)

# %%
df.isnull().sum()
# Out:
# capacity_mw              0
# latitude                 0
# longitude                0
# primary_fuel             0
# other_fuel1            709
# commissioning_year     380
# source                   0
# geolocation_source       0
# generation_gwh_2014    509
# generation_gwh_2015    485
# generation_gwh_2016    473
# generation_gwh_2017    467
# generation_gwh_2018    459
# dtype: int64

# %%
## Filling missing value using median and mode

# %%
#Finding what percentage of data is missing from the dataset
missing_values = df.isnull().sum().sort_values(ascending = False)
percentage_missing_values =(missing_values/len(df))*100
print(pd.concat([missing_values, percentage_missing_values], axis =1, keys =['Missing Values', '% Missing data']))
# Out:
#                      Missing Values  % Missing data
# other_fuel1                     709       78.169791
# generation_gwh_2014             509       56.119074
# generation_gwh_2015             485       53.472988
# generation_gwh_2016             473       52.149945
# generation_gwh_2017             467       51.488423
# generation_gwh_2018             459       50.606395
# commissioning_year              380       41.896362
# capacity_mw                       0        0.000000
# latitude                          0        0.000000
# longitude                         0        0.000000
# primary_fuel                      0        0.000000
# source                            0        0.000000
# geolocation_source                0        0.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %% [markdown]
# Now there is no missing value so  we are able to do EDA

# %% [markdown]
# <b> Before visualing feature let find details about Smallest & Biggest Powerplant </b>

# %%
df["other_fuel1"] = df["other_fuel1"].fillna(df["other_fuel1"].mode()[0])
df["commissioning_year"] = df["commissioning_year"].fillna(df["commissioning_year"].median())
df["generation_gwh_2014"] = df["generation_gwh_2014"].fillna(df["generation_gwh_2014"].median())
df["generation_gwh_2015"] = df["generation_gwh_2015"].fillna(df["generation_gwh_2015"].median())
df["generation_gwh_2016"] = df["generation_gwh_2016"].fillna(df["generation_gwh_2016"].median())
df["generation_gwh_2017"] = df["generation_gwh_2017"].fillna(df["generation_gwh_2017"].median())
df["generation_gwh_2018"] = df["generation_gwh_2018"].fillna(df["generation_gwh_2018"].median())

# %%
# after filling missing value again we will check the missing value available in the dataset or not

# %%
print('Minimum Capacity of Powerplant:',df.capacity_mw.min())
print('Maximum Capacity of Powerplant:',df.capacity_mw.max())
# Out:
# Minimum Capacity of Powerplant: 0.0
# Maximum Capacity of Powerplant: 4760.0

# %%
df.loc[df.capacity_mw==4760]
# Out:
#      capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 880       4760.0   24.0983    82.6719         Coal         Oil
#
#      commissioning_year                         source geolocation_source  \
# 880              2002.0  Central Electricity Authority                WRI
#
#      generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 880              27594.0              29047.0              30015.0
#
#      generation_gwh_2017  generation_gwh_2018
# 880              35116.0              35136.0

# %%
df.loc[df.capacity_mw==0]
# Out:
#      capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 829          0.0   12.8491    77.6752        Solar         Oil
#
#      commissioning_year                       source geolocation_source  \
# 829              2001.0  Tata BP Solar India Limited     Industry About
#
#      generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 829           801.123775           711.181225            737.20545
#
#      generation_gwh_2017  generation_gwh_2018
# 829            817.97725           751.644375

# %% [markdown]
# #### Comment :
# - <b> Biggest powerplant in India as per database is VINDH_CHAL STPS with Power generation capacity of 4760 MW.</b> As Name suggest it is Thermal powerplant with Coal as Primary Fuel and alternate fuel is oil. It is commission in year 2002.
# - Smallest power plant is mention as Tata BP - Electronics City Solar Panel Plant with capacity of 0 MW. <b>This must be data entry error as If powerplant is commission it cannot have capacity of 0 MW.</b>

# %%
plt.figure(figsize=(10,6))
sns.violinplot(df.capacity_mw)
plt.show()

# %% [markdown]
# <b> We can see there are very powerplant of capacity more than 1500 MW. Let check</b>

# %%
df.loc[df.capacity_mw >1500].shape
# Out:
# (39, 13)

# %%
pd.crosstab(df['capacity_mw'],df["primary_fuel"], margins=True).T.style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_d1cd1_row0_col0,#T_d1cd1_row0_col1,#T_d1cd1_row0_col2,#T_d1cd1_row0_col3,#T_d1cd1_row0_col4,#T_d1cd1_row0_col5,#T_d1cd1_row0_col6,#T_d1cd1_row0_col7,#T_d1cd1_row0_col8,#T_d1cd1_row0_col9,#T_d1cd1_row0_col10,#T_d1cd1_row0_col11,#T_d1cd1_row0_col12,#T_d1cd1_row0_col13,#T_d1cd1_row0_col14,#T_d1cd1_row0_col15,#T_d1cd1_row0_col16,#T_d1cd1_row0_col17,#T_d1cd1_row0_col18,#T_d1cd1_row0_col19,#T_d1cd1_row0_col20,#T_d1cd1_row0_col21,#T_d1cd1_row0_col22,#T_d1cd1_row0_col23,#T_d1cd1_row0_col24,#T_d1cd1_row0_col25,#T_d1cd1_row0_col26,#T_d1cd1_row0_col27,#T_d1cd1_row0_col28,#T_d1cd1_row0_col29,#T_d1cd1_row0_col30,#T_d1cd1_row0_col31,#T_d1cd1_row0_col32,#T_d1cd1_row0_col33,#T_d1cd1_row0_col34,#T_d1cd1_row0_col35,#T_d1cd1_row0_col37,#T_d1cd1_row0_col38,#T_d1cd1_row0_col41,#T_d1cd1_row0_col42,#T_d1cd1_row0_col43,#T_d1cd1_row0_col45,#T_d1cd1_row0_col47,#T_d1cd1_row0_col48,#T_d1cd1_row0_col49,#T_d1cd1_row0_col50,#T_d1cd1_row0_col51,#T_d1cd1_row0_col53,#T_d1cd1_row0_col54,#T_d1cd1_row0_col57,#T_d1cd1_row0_col59,#T_d1cd1_row0_col62,#T_d1cd1_row0_col64,#T_d1cd1_row0_col68,#T_d1cd1_row0_col69,#T_d1cd1_row0_col70,#T_d1cd1_row0_col71,#T_d1cd1_row0_col72,#T_d1cd1_row0_col74,#T_d1cd1_row0_col76,#T_d1cd1_row0_col78,#T_d1cd1_row0_col80,#T_d1cd1_row0_col82,#T_d1cd1_row0_col83,#T_d1cd1_row0_col84,#T_d1cd1_row0_col86,#T_d1cd1_row0_col87,#T_d1cd1_row0_col88,#T_d1cd1_row0_col90,#T_d1cd1_row0_col91,#T_d1cd1_row0_col92,#T_d1cd1_row0_col93,#T_d1cd1_row0_col95,#T_d1cd1_row0_col96,#T_d1cd1_row0_col97,#T_d1cd1_row0_col98,#T_d1cd1_row0_col99,#T_d1cd1_row0_col101,#T_d1cd1_row0_col102,#T_d1cd1_row0_col103,#T_d1cd1_row0_col104,#T_d1cd1_row0_col105,#T_d1cd1_row0_col106,#T_d1cd1_row0_col107,#T_d1cd1_row0_col108,#T_d1cd1_row0_col109,#T_d1cd1_row0_col110,#T_d1cd1_row0_col111,#T_d1cd1_row0_col112,#T_d1cd1_row0_col113,#T_d1cd1_row0_col115,#T_d1cd1_row0_col116,#T_d1cd1_row0_col117,#T_d1cd1_row0_col118,#T_d1cd1_row0_col119,#T_d1cd1_row0_col120,#T_d1cd1_row0_col121,#T_d1cd1_row0_col122,#T_d1cd1_row0_col123,#T_d1cd1_row0_col124,#T_d1cd1_row0_col125,#T_d1cd1_row0_col126,#T_d1cd1_row0_col127,#T_d1cd1_row0_col128,#T_d1cd1_row0_col129,#T_d1cd1_row0_col130,#T_d1cd1_row0_col131,#T_d1cd1_row0_col132,#T_d1cd1_row0_col133,#T_d1cd1_row0_col134,#T_d1cd1_row0_col136,#T_d1cd1_row0_col137,#T_d1cd1_row0_col138,#T_d1cd1_row0_col139,#T_d1cd1_row0_col140,#T_d1cd1_row0_col141,#T_d1cd1_row0_col142,#T_d1cd1_row0_col143,#T_d1cd1_row0_col144,#T_d1cd1_row0_col145,#T_d1cd1_row0_col146,#T_d1cd1_row0_col147,#T_d1cd1_row0_col148,#T_d1cd1_row0_col149,#T_d1cd1_row0_col150,#T_d1cd1_row0_col151,#T_d1cd1_row0_col152,#T_d1cd1_row0_col153,#T_d1cd1_row0_col154,#T_d1cd1_row0_col155,#T_d1cd1_row0_col156,#T_d1cd1_row0_col157,#T_d1cd1_row0_col158,#T_d1cd1_row0_col159,#T_d1cd1_row0_col160,#T_d1cd1_row0_col161,#T_d1cd1_row0_col162,#T_d1cd1_row0_col163,#T_d1cd1_row0_col164,#T_d1cd1_row0_col165,#T_d1cd1_row0_col166,#T_d1cd1_row0_col167,#T_d1cd1_row0_col168,#T_d1cd1_row0_col169,#T_d1cd1_row0_col170,#T_d1cd1_row0_col171,#T_d1cd1_row0_col172,#T_d1cd1_row0_col173,#T_d1cd1_row0_col174,#T_d1cd1_row0_col175,#T_d1cd1_row0_col176,#T_d1cd1_row0_col177,#T_d1cd1_row0_col178,#T_d1cd1_row0_col179,#T_d1cd1_row0_col180,#T_d1cd1_row0_col181,#T_d1cd1_row0_col182,#T_d1cd1_row0_col183,#T_d1cd1_row0_col184,#T_d1cd1_row0_col185,#T_d1cd1_row0_col186,#T_d1cd1_row0_col187,#T_d1cd1_row0_col188,#T_d1cd1_row0_col189,#T_d1cd1_row0_col190,#T_d1cd1_row0_col191,#T_d1cd1_row0_col192,#T_d1cd1_row0_col193,#T_d1cd1_row0_col194,#T_d1cd1_row0_col195,#T_d1cd1_row0_col196,#T_d1cd1_row0_col197,#T_d1cd1_row0_col198,#T_d1cd1_row0_col199,#T_d1cd1_row0_col200,#T_d1cd1_row0_col201,#T_d1cd1_row0_col202,#T_d1cd1_row0_col203,#T_d1cd1_row0_col204,#T_d1cd1_row0_col205,#T_d1cd1_row0_col206,#T_d1cd1_row0_col207,#T_d1cd1_row0_col208,#T_d1cd1_row0_col209,#T_d1cd1_row0_col210,#T_d1cd1_row0_col211,#T_d1cd1_row0_col212,#T_d1cd1_row0_col213,#T_d1cd1_row0_col214,#T_d1cd1_row0_col215,#T_d1cd1_row0_col216,#T_d1cd1_row0_col217,#T_d1cd1_row0_col218,#T_d1cd1_row0_col219,#T_d1cd1_row0 ...

# %%
plt.rcParams["figure.autolayout"] = True
sns.set_palette('husl')
f,ax=plt.subplots(1,2,figsize=(18,8))
df['primary_fuel'].value_counts().plot.pie(autopct='%2.1f%%',
                                          textprops ={ 'fontweight': 'bold','fontsize':13}, ax=ax[0],shadow=True)
ax[0].set_title('primary_fuel', fontsize=20,fontweight ='bold')
ax[0].set_ylabel('')
sns.countplot('primary_fuel',data=df,ax=ax[1])
ax[1].set_title('primary_fuel',fontsize=20,fontweight ='bold')
ax[1].set_xlabel("primary_fuel",fontsize=18,fontweight ='bold')
plt.show()

# %%
df.primary_fuel.value_counts()
# Out:
# Coal       258
# Hydro      251
# Solar      127
# Wind       123
# Gas         69
# Biomass     50
# Oil         20
# Nuclear      9
# Name: primary_fuel, dtype: int64

# %% [markdown]
# #### Comment:
# - Maximum Number of powerplant are coal based powerplant followed by Hydro energy based powerplants.
# - <b>Around 40 % Power plant are Unconventional powerplant mainly based on Non Renewable energy resorces.</b>
# - There are only 9 Nuclear powerplant. Usually these powerplant build for high capacity.<b> It will be interesting to look for capacity of these powerplant.</b>
#
# <b> Let find Total Generation capacity of all powerplant, afterwards we will look for capacity of powerplant according to fuel type.</b>

# %%
print('Total Power Generation Capacity of all Power Plants:',df['capacity_mw'].sum(),'MW')
# Out:
# Total Power Generation Capacity of all Power Plants: 295884.946 MW

# %% [markdown]
# India's Total Power Generation Capacity of is 295884.946 MW.
#
# Now Let's check sector wise Capacity.

# %%
df["capacity_mw"].groupby(df["primary_fuel"]).agg([sum])
# Out:
#                      sum
# primary_fuel
# Biomass         1003.260
# Coal          205839.220
# Gas            25172.506
# Hydro          46441.770
# Nuclear         8780.000
# Oil             1778.840
# Solar           2757.500
# Wind            4111.850

# %% [markdown]
# #### Comment :
# <b> Out of Total PowerGeneration Maximum comes from Coal.
#
# Here comes another interesting observation which we already suspected. Overall Power Generation capacity of Nuclear powerplants is greater than Unconventional Energy sources based powerplant (biomass, wind,solar) combined.</b>

# %%
#Lets check the relation between primary_fuel and  Average capacity_mw
plt.figure(figsize = (10,8))
y = df["capacity_mw"]
p = sns.barplot(x = "primary_fuel", y = "capacity_mw", data = df)
plt.title('Comparision between Primary fuel Type and Mean Capacity in mw', fontsize=22, fontweight='bold')
p.set_xlabel('Primary fuel Type',fontsize=18,fontweight ='bold')
p.set_ylabel('Mean Capacity in mw',fontsize=18,fontweight ='bold')
plt.xticks(fontsize=16,fontweight ='bold',rotation=30)
plt.yticks(fontsize=16,fontweight ='bold')
plt.show()

# %% [markdown]
# bove result is obvious as only 9 Nuclear powerplant so its mean Capacity is higher.

# %%
fig,axes=plt.subplots(2,2,figsize=(15,12))

# Checking generation growth in 2013
sns.barplot(x='primary_fuel',y='generation_gwh_2017',ax=axes[0,0],data=df)

# Checking generation growth in 2014
sns.barplot(x='primary_fuel',y='generation_gwh_2014',ax=axes[0,1],data=df)

# Checking generation growth in 2015
sns.barplot(x='primary_fuel',y='generation_gwh_2015',ax=axes[1,0],data=df,palette="Set2")

# Checking generation growth in 2016
sns.barplot(x='primary_fuel',y='generation_gwh_2016',ax=axes[1,1],data=df,palette="ch:.25")
plt.show()

# %% [markdown]
# #### Comment:
# - From the graph we can see that Nuclear has high mean electrical generation reports for all the years followed by Coal.
# Reason is high efficieny of Nuclear powerplants.
# - Other fuel types have very less contribution to power generation.

# %% [markdown]
# ### Location vs Primary Fuel

# %%
# Let's check how the primary_fuel is reated to longitude of the power plant
plt.figure(figsize=[10,6])
plt.style.use('ggplot')
plt.title('Comparision between longitude and primary_fuel')
a = sns.boxplot(df['primary_fuel'],df["longitude"])
a.set_xlabel('Primary fuel Type',fontsize=18,fontweight ='bold')
a.set_ylabel('longitude',fontsize=18,fontweight ='bold')
plt.show()

# %%
# Let's check how the primary_fuel is reated to Latitude of the power plant
plt.figure(figsize=[10,6])
plt.style.use('ggplot')
plt.title('Comparision between longitude and primary_fuel')
a = sns.boxplot(df['primary_fuel'],df["latitude"])
a.set_xlabel('Primary fuel Type',fontsize=18,fontweight ='bold')
a.set_ylabel('latitude',fontsize=18,fontweight ='bold')
plt.show()

# %% [markdown]
# #### Comment:
# - Location is important feature specially for Nuclear powerplants. These plants lies in between 15 to 25 latitude and longitudnal range of 75 to 88 degree.
# - We can also see  solar power plant are mostly establish in certain range of latitude and longitude. This might be due to clear and intense sunlight with minimum humidity.

# %% [markdown]
# ## Location vs Capacity

# %%
# Let's check how the capacity is reated to latitude of the power plant
plt.figure(figsize=[10,6])
plt.style.use('ggplot')
plt.title('Comparision between latitude and capacity_mw',fontsize=22, fontweight='bold')
a= sns.scatterplot(df['latitude'],df["capacity_mw"])
a.set_xlabel('Capacity',fontsize=18,fontweight ='bold')
a.set_ylabel('latitude',fontsize=18,fontweight ='bold')
plt.show()

# %%
# Let's check how the longitude related to the capacity of the power plant
plt.figure(figsize=[10,6])
plt.style.use('ggplot')
plt.title('Comparision between longitude and capacity_mw',fontsize=22, fontweight='bold')
a= sns.regplot(df['longitude'],df["capacity_mw"])
a.set_xlabel('Primary fuel Type',fontsize=18,fontweight ='bold')
a.set_ylabel('longitude',fontsize=18,fontweight ='bold')
plt.show()

# %% [markdown]
# No significant insight got from above plots

# %% [markdown]
# ## Commission age vs primary fuel

# %%
# Lets extract power plant age from commissioning year by subtracting it from the year 2018
df['Power_plant_age'] = 2018 - df['commissioning_year']
df.drop(columns=['commissioning_year'],inplace=True)

# %%
print('The oldest powerplant Age :',df.Power_plant_age.max())
print('The youngest powerplant Age :',df.Power_plant_age.min())
# Out:
# The oldest powerplant Age : 91.0
# The youngest powerplant Age : 0.0

# %%
df.loc[df.Power_plant_age==91]
# Out:
#      capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 728         42.0   12.3082     77.165        Hydro         Oil
#
#                             source geolocation_source  generation_gwh_2014  \
# 728  Central Electricity Authority                WRI            220.82035
#
#      generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 728             215.3777             144.4143            175.92595
#
#      generation_gwh_2018  Power_plant_age
# 728            282.76905             91.0

# %% [markdown]
# ***Oldest Powerplant is SIVASAMUNDRUM which is hydro power based plant with generation capacity of 42 MW.***

# %%
#Lets check how the power plant age affects Fuel Type
plt.figure(figsize = (10,6))
plt.title("Comparision between primary_fuel and Power plant age", fontsize=22, fontweight='bold')
a= sns.barplot(x = "primary_fuel", y = "Power_plant_age", data = df,palette="Set2")
a.set_xlabel('Primary fuel Type',fontsize=18,fontweight ='bold')
a.set_ylabel('Power_plant_age',fontsize=18,fontweight ='bold')
plt.show()

# %%
# Let's check how the Power_plant_age affects the capacity of the power plant
plt.figure(figsize=[10,6])
plt.title('Comparision between Power_plant_age and capacity_mw')
sns.regplot(df['Power_plant_age'],df['capacity_mw'],color = "g")
# Out:
# <AxesSubplot:title={'center':'Comparision between Power_plant_age and capacity_mw'}, xlabel='Power_plant_age', ylabel='capacity_mw'>

# %% [markdown]
# - There is negative linear relationship between feature and label.
# - We can say that the capacity of older plants is very less than compared to the powerplants which are stated recently.

# %%
#Lets check the relation between source and capacity_mw
plt.figure(figsize = (10,6))
sns.barplot(x = "geolocation_source", y = "capacity_mw", data = df)
plt.show()

# %%
labels='WRI','Industry About','National Renewable Energy Laboratory'
fig, ax = plt.subplots(figsize=(6,5))
ax.pie(df['geolocation_source'].value_counts(), labels=labels, autopct='%1.2f%%', shadow=True)
plt.show()

# %% [markdown]
# ***The capacity of geological source WRI is maximum which has capacity more than 350 megawatts. The geological source Industry About has less capacity.***

# %% [markdown]
# ## Distribution of features

# %%
# Now checking for numerical columns
Numerical=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        Numerical.append(i)
print(Numerical)
# Out:
# ['capacity_mw', 'latitude', 'longitude', 'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018', 'Power_plant_age']

# %%
Numerical=['capacity_mw', 'latitude', 'longitude', 'generation_gwh_2018', 'generation_gwh_2014', 'generation_gwh_2015',
           'generation_gwh_2016', 'generation_gwh_2017', 'Power_plant_age']

# %%
# Checking how the data has been distributed in each column

plt.figure(figsize=(20,15),facecolor='white')
plotnumber=1
for col in Numerical:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[col],color='b')
        plt.xlabel(col,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# ### Comment:
# - From the above distributionplot we can observe that the data is not normally distributed in all the columns except latitude and longitude.
# - In most of the columns the mean is greater than the median which means they are skewed to right.
# - We will remove the skewness in all these columns except the label later.

# %%
fig,axes=plt.subplots(2,2,figsize=(15,12))

# Checking generation growth in 2014
sns.scatterplot(x='generation_gwh_2014',y='capacity_mw',ax=axes[0,0],data=df,color="g")

# Checking generation growth in 2015
sns.scatterplot(x='generation_gwh_2015',y='capacity_mw',ax=axes[0,1],data=df,color="indigo")

# Checking generation growth in 2016
sns.scatterplot(x='generation_gwh_2016',y='capacity_mw',ax=axes[1,0],data=df,color="g")

# Checking generation growth in 2017
sns.scatterplot(x='generation_gwh_2017',y='capacity_mw',ax=axes[1,1],data=df,color="r")
plt.show()

# %% [markdown]
# #### Observation:
# - There is a positive linear relationship between the capacity and the electricity generation reported for the years mentioned.
# - The plot shows the electricity generation reported for the years 2014,2015,2016,2017 have high capacity of above 1000mw. Also the power generation growth is more than 5000gwh in all the years.
# - As the electricity generation growth increases, the capacity of plant also increases.

# %%
#Distribution plot for all numerical columns
for i in df[Numerical]:              
    plt.figure(figsize = (8, 4))
    sns.distplot(df[i], bins = 10, color="indigo")
    plt.title(i)
    plt.show()

# %%
#Checking the pairwise relation between the features and label capacity in megawatt.
sns.pairplot(df)

# %% [markdown]
# ####  Comment:
# - Most of the features have strong linear relationship and correlation with each other.
# - From the plot we can observe the outliers in some of the columns.
# - We can see histogram on the diagonal.

# %%
# checking for categorical columns
Categorical=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        Categorical.append(i)
print(Categorical)
# Out:
# ['primary_fuel', 'other_fuel1', 'source', 'geolocation_source']

# %% [markdown]
# ## Encoding categorical data

# %%
# Using Label Encoder on categorical variable
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in Categorical:
    df[i] = le.fit_transform(df[i])
df.head()
# Out:
#    capacity_mw  latitude  longitude  primary_fuel  other_fuel1  source  \
# 0          2.5   28.1839    73.2407             6            2     109
# 1         98.0   24.7663    74.6090             1            2     174
# 2         39.2   21.9038    69.3732             7            2      21
# 3        135.0   23.8712    91.3602             2            2      22
# 4       1800.0   21.9603    82.4091             1            2      22
#
#    geolocation_source  generation_gwh_2014  generation_gwh_2015  \
# 0                   1           801.123775           711.181225
# 1                   2           801.123775           711.181225
# 2                   2           801.123775           711.181225
# 3                   2           617.789264           843.747000
# 4                   2          3035.550000          5916.370000
#
#    generation_gwh_2016  generation_gwh_2017  generation_gwh_2018  \
# 0           737.205450           817.977250           751.644375
# 1           737.205450           817.977250           751.644375
# 2           737.205450           817.977250           751.644375
# 3           886.004428           663.774500           626.239128
# 4          6243.000000          5385.579736          7279.000000
#
#    Power_plant_age
# 0              7.0
# 1             17.0
# 2             17.0
# 3             14.0
# 4              3.0

# %% [markdown]
# ## Outliers detection and removal

# %%
# Identifying the outliers present in numerical columns using boxplot

plt.figure(figsize=(20,25))
plotnumber=1
for col in Numerical:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(df[col],color='cyan')
        plt.xlabel(col,fontsize=12)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# #### Comment :
# - There outliers exist in data.
# - There are no outliers in lower capping level.
# - So we will use Quantile-based Flooring and Capping technique.
#
# ### Further outliers investigation will be done bases Quantile-based Flooring and Capping technique. In this technique, we will do the flooring (e.g., the 10th percentile) for the lower values and capping (e.g., the 75th percentile) for the higher values

# %%
# Removal of unnessary columns
df.drop(columns=['source','geolocation_source'],axis=1,inplace=True)

# %%
df2=df.copy

# %%
#Distribution plot for all numerical columns
for i in df[Numerical]:              
    plt.figure(figsize = (8, 4))
    sns.distplot(df[i], bins = 10, color="indigo")
    plt.title(i)
    plt.show()

# %%
df3=df.copy()
Q1 = df3.quantile(0)
Q3= df3.quantile(0.85)
IQR = Q3 - Q1
print(IQR)
# Out:
# capacity_mw             720.000000
# latitude                 19.198860
# longitude                13.304440
# primary_fuel              6.000000
# other_fuel1               2.000000
# generation_gwh_2014    1856.927800
# generation_gwh_2015    2298.962020
# generation_gwh_2016    2435.205000
# generation_gwh_2017    2622.083625
# generation_gwh_2018    2688.268830
# Power_plant_age          29.000000
# dtype: float64

# %%
data = df3[~((df3 < (Q1 - 1.5 * IQR)) |(df3 > (Q3 + 1.5 * IQR))).any(axis=1)]
print(data.shape)
# Out:
# (813, 11)

# %%
print("\033[1m"+'Percentage Data Loss :'+"\033[0m",((908-813)/813)*100,'%')
# Out:
# Percentage Data Loss : 11.685116851168512 %

# %%
#Features having outliers
features=df[['longitude','generation_gwh_2018','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017','Power_plant_age']]

# %%
from scipy.stats import zscore
z=np.abs(zscore(features))
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#      capacity_mw  latitude  longitude  primary_fuel  other_fuel1  \
# 0            2.5   28.1839    73.2407             6            2
# 1           98.0   24.7663    74.6090             1            2
# 2           39.2   21.9038    69.3732             7            2
# 3          135.0   23.8712    91.3602             2            2
# 4         1800.0   21.9603    82.4091             1            2
# ..           ...       ...        ...           ...          ...
# 902       1600.0   16.2949    77.3568             1            2
# 903          3.0   12.8932    78.1654             6            2
# 904         25.5   15.2758    75.5811             7            2
# 905         80.0   24.3500    73.7477             1            2
# 906         16.5    9.9344    77.4768             7            2
#
#      generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0             801.123775           711.181225           737.205450
# 1             801.123775           711.181225           737.205450
# 2             801.123775           711.181225           737.205450
# 3             617.789264           843.747000           886.004428
# 4            3035.550000          5916.370000          6243.000000
# ..                   ...                  ...                  ...
# 902           801.123775             0.994875           233.596650
# 903           801.123775           711.181225           737.205450
# 904           801.123775           711.181225           737.205450
# 905           801.123775           711.181225           737.205450
# 906           801.123775           711.181225           737.205450
#
#      generation_gwh_2017  generation_gwh_2018  Power_plant_age
# 0             817.977250           751.644375              7.0
# 1             817.977250           751.644375             17.0
# 2             817.977250           751.644375             17.0
# 3             663.774500           626.239128             14.0
# 4            5385.579736          7279.000000              3.0
# ..                   ...                  ...              ...
# 902           865.400000           686.500000              2.0
# 903           817.977250           751.644375             17.0
# 904           817.977250           751.644375             17.0
# 905           817.977250           751.644375             17.0
# 906           817.977250           751.644375             17.0
#
# [851 rows x 11 columns]

# %%
#Checking shape of new dataset
df_new.shape
# Out:
# (851, 11)

# %%
#Checking shape of old dataset
df.shape
# Out:
# (907, 11)

# %%
#Checking dataloss
Dataloss = (((907-851)/907)*100)
Dataloss
# Out:
# 6.174200661521499

# %% [markdown]
# Using Zscore i have 6.17% data loss.Which is less than 10%

# %% [markdown]
# There is a great dataloss in IQR method so let me stick on to zscore method to remove outliers.

# %% [markdown]
# ## Correlation Matrix

# %%
plt.figure(figsize=(21,13))
sns.heatmap(df_new.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f', 
            annot_kws={'size':10}, cmap="cool")
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %% [markdown]
# - The label capacity_mw is highly positively  correlated with the features generation_gwh_2018,generation_gwh_2017,generation_gwh_2016,generation_gwh_2015,generation_gwh_2014.
# - capaity is negatively correlated with the features primary_fuel, source and Powe_plant_age.

# %%
plt.figure(figsize=(14,7))
data.corr()['capacity_mw'].sort_values(ascending=False).drop(['capacity_mw']).plot(kind='bar',color='c')
plt.xlabel('Features',fontsize=10)
plt.ylabel('Capacity',fontsize=10)
plt.title('Correlation between capacity and features using bar plot',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(14,7))
data.corr()['primary_fuel'].sort_values(ascending=False).drop(['capacity_mw']).plot(kind='bar',color='c')
plt.xlabel('Features',fontsize=10)
plt.ylabel('primary_fuel',fontsize=10)
plt.title('Correlation between primary_fuel and features using bar plot',fontsize=20)
plt.show()

# %% [markdown]
# ## Now Will check Sknewss

# %%
df_new.skew()
# Out:
# capacity_mw             2.170245
# latitude               -0.119551
# longitude               0.945877
# primary_fuel            0.413759
# other_fuel1           -19.809189
# generation_gwh_2014     2.943026
# generation_gwh_2015     2.714999
# generation_gwh_2016     2.645786
# generation_gwh_2017     2.546541
# generation_gwh_2018     2.597029
# Power_plant_age         1.280800
# dtype: float64

# %%
skew = ['longitude','other_fuel1','generation_gwh_2018','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017','Power_plant_age']
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method = 'yeo-johnson')

# %%
df_new[skew] = scaler.fit_transform(df_new[skew].values)
df_new[skew].head()
# Out:
#    longitude  other_fuel1  generation_gwh_2018  generation_gwh_2014  \
# 0  -0.922012     0.059479            -0.057181            -0.044061
# 1  -0.499829     0.059479            -0.057181            -0.044061
# 2  -2.377759     0.059479            -0.057181            -0.044061
# 3   2.430594     0.059479            -0.194159            -0.268922
# 4   1.261979     0.059479             2.347272             1.426798
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0            -0.049141            -0.046103            -0.035226
# 1            -0.049141            -0.046103            -0.035226
# 2            -0.049141            -0.046103            -0.035226
# 3             0.093773             0.105691            -0.199692
# 4             2.286603             2.276671             1.983083
#
#    Power_plant_age
# 0        -1.081421
# 1         0.046187
# 2         0.046187
# 3        -0.245810
# 4        -1.758384

# %%
# checking skewness after using yeo-johnson
df_new.skew()
# Out:
# capacity_mw             2.170245
# latitude               -0.119551
# longitude              -0.000128
# primary_fuel            0.413759
# other_fuel1           -16.782811
# generation_gwh_2014     0.232399
# generation_gwh_2015     0.163587
# generation_gwh_2016     0.147035
# generation_gwh_2017     0.127152
# generation_gwh_2018     0.133691
# Power_plant_age         0.043734
# dtype: float64

# %%
# We will drop other fuel as result of poor correlation and lot of missing values
df_new.drop("other_fuel1",axis=1,inplace=True)
# Missing Value Imputation of latitude with mean
df_new['Power_plant_age'] = df_new['Power_plant_age'].fillna(df_new['Power_plant_age'].mean())

# %% [markdown]
# ## Machine Learning Model Building Classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score

# %% [markdown]
# ## Standard Scaling

# %%
# Splitting data in target and dependent feature
X = df_new.drop(['primary_fuel'], axis =1)
Y = df_new['primary_fuel']

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif["vif_Features"]=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["Features"]=X.columns
vif
# Out:
#    vif_Features             Features
# 0      2.450519          capacity_mw
# 1      1.622447             latitude
# 2      1.107668            longitude
# 3      3.603396  generation_gwh_2014
# 4      6.201438  generation_gwh_2015
# 5      9.967246  generation_gwh_2016
# 6      9.856449  generation_gwh_2017
# 7      9.065874  generation_gwh_2018
# 8      1.157328      Power_plant_age

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %% [markdown]
# ## Balancing the target variable using oversampling:

# %%
Y.value_counts()
# Out:
# 1    238
# 3    220
# 6    126
# 7    123
# 2     65
# 0     50
# 5     20
# 4      9
# Name: primary_fuel, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
SM = SMOTE()
X_scale, Y = SM.fit_resample(X_scale,Y)

# %%
Y.value_counts()
# Out:
# 0    238
# 1    238
# 2    238
# 3    238
# 4    238
# 5    238
# 6    238
# 7    238
# Name: primary_fuel, dtype: int64

# %%
# Visualizing the data after oversampling
sns.countplot(Y)
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='count'>

# %% [markdown]
# Since all the VIF features are less than 10 so no need to remove any column.
#
# Now the multicolinearity issue is resolved.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=99, test_size=.3)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (1332, 9)
# Training target vector size: (1332,)
# Test feature matrix size: (572, 9)
# Test target vector size: (572,)

# %% [markdown]
# ## Finding best Random state

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report,f1_score
maxAccu=0
maxRS=0
for i in range(1,200):
    X_train,X_test,Y_train,Y_test = train_test_split(X_scale,Y,test_size = 0.3, random_state=i)
    log_reg=LogisticRegression()
    log_reg.fit(X_train,Y_train)
    y_pred=log_reg.predict(X_test)
    acc=accuracy_score(Y_test,y_pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best accuracy is', maxAccu ,'on Random_state', maxRS)
# Out:
# Best accuracy is 0.548951048951049 on Random_state 127

# %% [markdown]
# ## Logistics Regression Model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=148, test_size=.3)
log_reg=LogisticRegression()
log_reg.fit(X_train,Y_train)
y_pred=log_reg.predict(X_test)
print('\033[1m'+'Logistics Regression Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of Logistics Regression :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Logistics Regression :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of Logistics Regression'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Logistics Regression Evaluation
#
#
# Accuracy Score of Logistics Regression : 0.5122377622377622
#
#
# Confusion matrix of Logistics Regression :
#  [[46  0  0  0  0  0  6 23]
#  [ 7 28  8  4  8  0  7  3]
#  [ 1 15 20  5  5  8  3  9]
#  [ 7  9  5 35  5  9  4  3]
#  [ 0  5  0  5 68  0  0  0]
#  [ 1  0  0  3  1 35  0 23]
#  [ 6  2  0  2  0  9 49  3]
#  [30  0  2  1  0  6 26 12]]
#
#
# classification Report of Logistics Regression
#                precision    recall  f1-score   support
#
#            0       0.47      0.61      0.53        75
#            1       0.47      0.43      0.45        65
#            2       0.57      0.30      0.40        66
#            3       0.64      0.45      0.53        77
#            4       0.78      0.87      0.82        78
#            5       0.52      0.56      0.54        63
#            6       0.52      0.69      0.59        71
#            7       0.16      0.16      0.16        77
#
#     accuracy                           0.51       572
#    macro avg       0.52      0.51      0.50       572
# weighted avg       0.52      0.51      0.50       572

# %%
cm = confusion_matrix(Y_test, y_pred)

x_axis_labels = ["Biomass","Coal","Gas","Hydro","Nuclear","Oil","Solar","Wind"]
y_axis_labels = ["Biomass","Coal","Gas","Hydro","Nuclear","Oil","Solar","Wind"]

f, ax = plt.subplots(figsize =(7,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Purples", xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Logistics Regression')
plt.show()

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(log_reg, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', log_reg, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score LogisticRegression() :
#
# CVScore : [0.51968504 0.5511811  0.48293963 0.48818898 0.49736842]
# Mean CV Score : 0.5078726343417599
# Std deviation : 0.02503835370403319

# %% [markdown]
# ## DecisionTreeClassifier Model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=148, test_size=.3)
DTC=DecisionTreeClassifier()
DTC.fit(X_train,Y_train)
preddt=DTC.predict(X_test)
print('Accuracy Score:',accuracy_score(Y_test, preddt))
print('Confusion Matrix:',confusion_matrix(Y_test, preddt))
print(classification_report(Y_test,preddt))
# Out:
# Accuracy Score: 0.8444055944055944
# Confusion Matrix: [[69  1  0  0  0  0  0  5]
#  [ 4 44  3  3  4  2  2  3]
#  [ 0  5 56  2  1  2  0  0]
#  [ 0  9  6 56  0  2  2  2]
#  [ 0  6  0  0 72  0  0  0]
#  [ 0  1  0  1  0 61  0  0]
#  [ 4  5  0  0  0  1 58  3]
#  [ 1  1  2  0  0  0  6 67]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90        75
#            1       0.61      0.68      0.64        65
#            2       0.84      0.85      0.84        66
#            3       0.90      0.73      0.81        77
#            4       0.94      0.92      0.93        78
#            5       0.90      0.97      0.93        63
#            6       0.85      0.82      0.83        71
#            7       0.84      0.87      0.85        77
#
#     accuracy                           0.84       572
#    macro avg       0.84      0.84      0.84       572
# weighted avg       0.85      0.84      0.84       572

# %%
cm = confusion_matrix(Y_test, preddt)

x_axis_labels = ["Biomass","Coal","Gas","Hydro","Nuclear","Oil","Solar","Wind"]
y_axis_labels = ["Biomass","Coal","Gas","Hydro","Nuclear","Oil","Solar","Wind"]

f, ax = plt.subplots(figsize =(7,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Purples", xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Decision Tree Classifier')
plt.show()

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(DTC, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', DTC, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score DecisionTreeClassifier() :
#
# CVScore : [0.80314961 0.83464567 0.86089239 0.84251969 0.84473684]
# Mean CV Score : 0.8371888382373255
# Std deviation : 0.019038831907419965

# %% [markdown]
# ## Random Forest Classifier Model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=148, test_size=.3)
RFC=RandomForestClassifier()
RFC.fit(X_train,Y_train)
predrf=RFC.predict(X_test)
print('Accuracy Score:',accuracy_score(Y_test, predrf))
print('Confusion Matrix:',confusion_matrix(Y_test, predrf))
print(classification_report(Y_test,predrf))
# Out:
# Accuracy Score: 0.8846153846153846
# Confusion Matrix: [[72  0  0  0  0  0  0  3]
#  [ 7 45  7  2  2  1  0  1]
#  [ 0  2 61  0  0  2  0  1]
#  [ 0  6  5 61  1  1  1  2]
#  [ 0  1  2  0 75  0  0  0]
#  [ 0  0  0  0  0 62  0  1]
#  [ 3  3  0  0  0  0 64  1]
#  [ 2  1  1  0  0  0  7 66]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91        75
#            1       0.78      0.69      0.73        65
#            2       0.80      0.92      0.86        66
#            3       0.97      0.79      0.87        77
#            4       0.96      0.96      0.96        78
#            5       0.94      0.98      0.96        63
#            6       0.89      0.90      0.90        71
#            7       0.88      0.86      0.87        77
#
#     accuracy                           0.88       572
#    macro avg       0.88      0.88      0.88       572
# weighted avg       0.89      0.88      0.88       572

# %%
cm = confusion_matrix(Y_test, predrf)

x_axis_labels = ["Biomass","Coal","Gas","Hydro","Nuclear","Oil","Solar","Wind"]
y_axis_labels = ["Biomass","Coal","Gas","Hydro","Nuclear","Oil","Solar","Wind"]

f, ax = plt.subplots(figsize =(7,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Purples", xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Random Forest Classifier')
plt.show()

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(RFC, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', RFC, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score RandomForestClassifier() :
#
# CVScore : [0.86351706 0.87664042 0.90551181 0.90551181 0.88684211]
# Mean CV Score : 0.8876046415250725
# Std deviation : 0.016384996925706868

# %% [markdown]
# ## Support Vector Machine Model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=148, test_size=.3)
SV=SVC()
SV.fit(X_train,Y_train)
predsv=SV.predict(X_test)
print('Accuracy Score:',accuracy_score(Y_test, predsv))
print('Confusion Matrix:',confusion_matrix(Y_test, predsv))
print(classification_report(Y_test,predsv))
# Out:
# Accuracy Score: 0.7045454545454546
# Confusion Matrix: [[69  0  0  0  0  0  6  0]
#  [ 9 35  5  2  3  0 11  0]
#  [ 1  7 35  1  2 14  5  1]
#  [ 7  7  5 52  1  2  0  3]
#  [ 0  0  0  1 77  0  0  0]
#  [ 6  0  0  0  0 57  0  0]
#  [ 7  0  0  0  0  5 59  0]
#  [35  0  0  0  0  5 18 19]]
#               precision    recall  f1-score   support
#
#            0       0.51      0.92      0.66        75
#            1       0.71      0.54      0.61        65
#            2       0.78      0.53      0.63        66
#            3       0.93      0.68      0.78        77
#            4       0.93      0.99      0.96        78
#            5       0.69      0.90      0.78        63
#            6       0.60      0.83      0.69        71
#            7       0.83      0.25      0.38        77
#
#     accuracy                           0.70       572
#    macro avg       0.75      0.70      0.69       572
# weighted avg       0.75      0.70      0.69       572

# %%
cm = confusion_matrix(Y_test, predsv)

x_axis_labels = ["Biomass","Coal","Gas","Hydro","Nuclear","Oil","Solar","Wind"]
y_axis_labels = ["Biomass","Coal","Gas","Hydro","Nuclear","Oil","Solar","Wind"]

f, ax = plt.subplots(figsize =(7,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Purples", xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Support Vector Classifier')
plt.show()

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(SV, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', SV, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score SVC() :
#
# CVScore : [0.7191601  0.68503937 0.71128609 0.70341207 0.68157895]
# Mean CV Score : 0.7000953170327393
# Std deviation : 0.014623528164808051

# %% [markdown]
# ## K Nearest Neighbor Classifier Model

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=148, test_size=.3)
knn=KNeighborsClassifier()
knn.fit(X_train,Y_train)
predkn=knn.predict(X_test)
print('Accuracy Score:',accuracy_score(Y_test, predkn))
print('Confusion Matrix:',confusion_matrix(Y_test, predkn))
print(classification_report(Y_test,predkn))
# Out:
# Accuracy Score: 0.8164335664335665
# Confusion Matrix: [[71  0  0  0  0  0  1  3]
#  [ 9 39  7  2  3  2  1  2]
#  [ 1  5 47  2  0  8  3  0]
#  [ 4 11  1 55  0  1  0  5]
#  [ 0  0  1  1 76  0  0  0]
#  [ 1  0  0  0  0 61  0  1]
#  [ 5  7  0  0  0  0 57  2]
#  [ 7  0  0  0  0  2  7 61]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.95      0.82        75
#            1       0.63      0.60      0.61        65
#            2       0.84      0.71      0.77        66
#            3       0.92      0.71      0.80        77
#            4       0.96      0.97      0.97        78
#            5       0.82      0.97      0.89        63
#            6       0.83      0.80      0.81        71
#            7       0.82      0.79      0.81        77
#
#     accuracy                           0.82       572
#    macro avg       0.82      0.81      0.81       572
# weighted avg       0.82      0.82      0.81       572

# %%
cm = confusion_matrix(Y_test, predkn)

x_axis_labels = ["Biomass","Coal","Gas","Hydro","Nuclear","Oil","Solar","Wind"]
y_axis_labels = ["Biomass","Coal","Gas","Hydro","Nuclear","Oil","Solar","Wind"]

f, ax = plt.subplots(figsize =(7,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Purples", xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for K-Neighbor Classifier')
plt.show()

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(knn, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', knn, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score KNeighborsClassifier() :
#
# CVScore : [0.82677165 0.81627297 0.80052493 0.82414698 0.82105263]
# Mean CV Score : 0.8177538334024037
# Std deviation : 0.009296272626850352

# %% [markdown]
# ## Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=148, test_size=.3)
GBC=GradientBoostingClassifier()
GBC.fit(X_train,Y_train)
predgb=GBC.predict(X_test)
print('Accuracy Score:',accuracy_score(Y_test, predgb))
print('Confusion Matrix:',confusion_matrix(Y_test, predgb))
print(classification_report(Y_test,predgb))
# Out:
# Accuracy Score: 0.8793706293706294
# Confusion Matrix: [[70  0  0  0  0  0  0  5]
#  [ 6 49  2  3  1  1  1  2]
#  [ 0  2 58  1  0  4  0  1]
#  [ 0  6  5 62  0  1  1  2]
#  [ 0  1  2  0 75  0  0  0]
#  [ 0  1  1  0  0 61  0  0]
#  [ 5  2  0  0  0  0 63  1]
#  [ 3  3  0  0  0  0  6 65]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88        75
#            1       0.77      0.75      0.76        65
#            2       0.85      0.88      0.87        66
#            3       0.94      0.81      0.87        77
#            4       0.99      0.96      0.97        78
#            5       0.91      0.97      0.94        63
#            6       0.89      0.89      0.89        71
#            7       0.86      0.84      0.85        77
#
#     accuracy                           0.88       572
#    macro avg       0.88      0.88      0.88       572
# weighted avg       0.88      0.88      0.88       572

# %%
cm = confusion_matrix(Y_test, predgb)

x_axis_labels = ["Biomass","Coal","Gas","Hydro","Nuclear","Oil","Solar","Wind"]
y_axis_labels = ["Biomass","Coal","Gas","Hydro","Nuclear","Oil","Solar","Wind"]

f, ax = plt.subplots(figsize =(7,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Purples", xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Gradient Boosting Classifier')
plt.show()

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(GBC, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', GBC, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score GradientBoostingClassifier() :
#
# CVScore : [0.84776903 0.87401575 0.88713911 0.87139108 0.88947368]
# Mean CV Score : 0.8739577289680895
# Std deviation : 0.01487906378681033

# %% [markdown]
# ## Extra Tree Classifier

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=148, test_size=.3)
etc=ExtraTreesClassifier()
etc.fit(X_train,Y_train)
y_pred=etc.predict(X_test)
print('\033[1m'+'ExtraTreesClassifier Evaluation'+'\033[0m')
print('\n')
print('\033[1m'+'Accuracy Score of ExtraTreesClassifier :'+'\033[0m', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of ExtraTreesClassifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'classification Report of ExtraTreesClassifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# ExtraTreesClassifier Evaluation
#
#
# Accuracy Score of ExtraTreesClassifier : 0.8933566433566433
#
#
# Confusion matrix of ExtraTreesClassifier :
#  [[71  0  0  0  0  0  0  4]
#  [ 4 46  6  2  3  1  0  3]
#  [ 0  3 59  1  0  2  0  1]
#  [ 0  6  4 63  0  1  1  2]
#  [ 0  1  0  0 77  0  0  0]
#  [ 0  0  0  0  0 62  0  1]
#  [ 2  3  0  0  0  0 63  3]
#  [ 2  1  0  0  0  0  4 70]]
#
#
# classification Report of ExtraTreesClassifier
#                precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92        75
#            1       0.77      0.71      0.74        65
#            2       0.86      0.89      0.87        66
#            3       0.95      0.82      0.88        77
#            4       0.96      0.99      0.97        78
#            5       0.94      0.98      0.96        63
#            6       0.93      0.89      0.91        71
#            7       0.83      0.91      0.87        77
#
#     accuracy                           0.89       572
#    macro avg       0.89      0.89      0.89       572
# weighted avg       0.89      0.89      0.89       572

# %%
cm = confusion_matrix(Y_test, y_pred)

x_axis_labels = ["Biomass","Coal","Gas","Hydro","Nuclear","Oil","Solar","Wind"]
y_axis_labels = ["Biomass","Coal","Gas","Hydro","Nuclear","Oil","Solar","Wind"]

f, ax = plt.subplots(figsize =(7,7))
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", ax=ax, cmap="Purples", xticklabels=x_axis_labels, yticklabels=y_axis_labels)
plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for ExtraTreesClassifier')
plt.show()

# %%
from sklearn.model_selection import cross_val_score
CVscore = cross_val_score(etc, X_scale, Y, cv =5)
print('\033[1m'+'Cross Validation Score', etc, ':'+'\033[0m\n')
print("CVScore :" ,CVscore)
print("Mean CV Score :",CVscore.mean())
print("Std deviation :",CVscore.std())
# Out:
# Cross Validation Score ExtraTreesClassifier() :
#
# CVScore : [0.91076115 0.88188976 0.9160105  0.92125984 0.92368421]
# Mean CV Score : 0.9107210940737671
# Std deviation : 0.01508862233300291

# %% [markdown]
# ## Summerizing all ML model Accuracy, F1score and CVScore by using Prettytable

# %%
from prettytable import PrettyTable
x=PrettyTable()

# %%
x.field_names=['Model_Name','Train_AUC(X_train)','f1-Score','CVScore']

# %%
x.add_row(['Logistic_Regression',57.51,58.00,52.94])
x.add_row(['DecisionTreeClassifier',80.41,80.00,81.88])
x.add_row(['RandomForestClassifier',86.53,87,89.23])
x.add_row(['SupportVectorMachine',71.67,72.00,71.90])
x.add_row(['KNeighbourNearestClassifier',81.29,81.00,82.40])
x.add_row(['GradientBoostClassifier',85.31,85.00,87.02])
x.add_row(['ExtraTreeClassifier',89.33,89.00,91.07])

# %%
print(x)
# Out:
# +-----------------------------+--------------------+----------+---------+
# |          Model_Name         | Train_AUC(X_train) | f1-Score | CVScore |
# +-----------------------------+--------------------+----------+---------+
# |     Logistic_Regression     |       57.51        |   58.0   |  52.94  |
# |    DecisionTreeClassifier   |       80.41        |   80.0   |  81.88  |
# |    RandomForestClassifier   |       86.53        |    87    |  89.23  |
# |     SupportVectorMachine    |       71.67        |   72.0   |   71.9  |
# | KNeighbourNearestClassifier |       81.29        |   81.0   |   82.4  |
# |   GradientBoostClassifier   |       85.31        |   85.0   |  87.02  |
# |     ExtraTreeClassifier     |       87.58        |   88.0   |  91.01  |
# |     Logistic_Regression     |       57.51        |   58.0   |  52.94  |
# |    DecisionTreeClassifier   |       80.41        |   80.0   |  81.88  |
# |    RandomForestClassifier   |       86.53        |    87    |  89.23  |
# |     SupportVectorMachine    |       71.67        |   72.0   |   71.9  |
# | KNeighbourNearestClassifier |       81.29        |   81.0   |   82.4  |
# |   GradientBoostClassifier   |       85.31        |   85.0   |  87.02  |
# |     ExtraTreeClassifier     |       89.33        |   89.0   |  91.07  |
# +-----------------------------+--------------------+----------+---------+

# %% [markdown]
# From the above summary of Various model accuracy it can easily insights that we have good accuracy and F1 socre  in EXtra Tree Classifier Model.
#
# ## So, here We will would like to declare that Extra Tree Regressor is our best Model for Classification Problem

# %% [markdown]
# ### Now we will do hyper tunning on our best model

# %%
from sklearn.model_selection import GridSearchCV

# %%
param = parameter= {'criterion' : ['gini', 'entropy'],
              'min_samples_split':[3,5,8],
              'max_depth' : [20,30,40],
              'n_estimators' : [100, 150, 200]
             }

# %%
GCV = GridSearchCV(ExtraTreesClassifier(),param,verbose=5)
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.884 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.884 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.876 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.898 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.895 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.873 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.891 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.876 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.883 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.887 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.884 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.888 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.876 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.895 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.891 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.880 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.895 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.865 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.872 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.876 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.873 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.888 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.868 total time=   0.6s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.865 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.872 total time=   0.3s
# Collecting xgboost
#   Downloading xgboost-1.6.0-py3-none-win_amd64.whl (126.1 MB)
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 171, in _merge_into_criterion
#     crit = self.state.criteria[name]
# KeyError: 'xgboost'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 519, in read
#     data = self._fp.read(amt) if not fp_closed else b""
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_vendor\cachecontrol\filewrapper.py", line 62, in read
#     data = self.__fp.read(amt)
#   File "C:\Users\DataLab\anaconda3\lib\http\client.py", line 458, in read
#     n = self.readinto(b)
#   File "C:\Users\DataLab\anaconda3\lib\http\client.py", line 502, in readinto
#     n = self.fp.readinto(b)
#   File "C:\Users\DataLab\anaconda3\lib\socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
#   File "C:\Users\DataLab\anaconda3\lib\ssl.py", line 1241, in recv_into
#     return self.read(nbytes, buffer)
#   File "C:\Users\DataLab\anaconda3\lib\ssl.py", line 1099, in read
#     return self._sslobj.read(len, buffer)
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_internal\cli\base_command.py", line 189, in _main
#     status = self.run(options, args)
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_internal\cli\req_command.py", line 178, in wrapper
#     return func(self, options, args)
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_internal\commands\install.py", line 316, in run
#     requirement_set = resolver.resolve(
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\resolver.py", line 121, in resolve
#     self._result = resolver.resolve(
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 453, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 318, in resolve
#     name, crit = self._merge_into_criterion(r, parent=None)
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 173, in _merge_into_criterion
#     crit = Criterion.from_requirement(self._p, requirement, parent)
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_vendor\resolvelib\resolvers.py", line 82, in from_requirement
#     if not cands:
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_vendor\resolvelib\structs.py", line 124, in __bool__
#     return bool(self._sequence)
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 143, in __bool__
#     return any(self)
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\found_candidates.py", line 38, in _iter_built
#     candidate = func()
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\factory.py", line 167, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 300, in __init__
#     super().__init__(
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 144, in __init__
#     self.dist = self._prepare()
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 226, in _prepare
#     dist = self._prepare_distribution()
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_internal\resolution\resolvelib\candidates.py", line 311, in _prepare_distribution
#     return self._factory.preparer.prepare_linked_requirement(
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 457, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 480, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 230, in unpack_url
#     file = get_http_url(
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_internal\operations\prepare.py", line 108, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_internal\network\download.py", line 163, in __call__
#     for chunk in chunks:
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_internal\cli\progress_bars.py", line 159, in iter
#     for x in it:
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_internal\network\utils.py", line 64, in response_chunks
#     for chunk in response.raw.stream(
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 576, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 541, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "C:\Users\DataLab\anaconda3\lib\contextlib.py", line 131, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Users\DataLab\anaconda3\lib\site-packages\pip\_vendor\urllib3\response.py", line 455, in _error_catcher
#     raise ProtocolError("Connection broken: %r" % e, e)
# pip._vendor.urllib3.exceptions.ProtocolError: ("Connection broken: ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None)", ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.876 total time=   1.0s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.895 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.883 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.872 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.880 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.884 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.891 total time=   0.2s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.876 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.880 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.872 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.876 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.891 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.872 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.880 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.861 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.876 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.891 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.872 total time=   0.7s
# [CV 4/5] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.876 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.868 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.891 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.903 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.880 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.906 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.898 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.884 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.888 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.895 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.902 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.898 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.891 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.899 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.895 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.910 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.891 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.888 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.903 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.883 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.902 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.883 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.891 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.899 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.891 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.898 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.895 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.880 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.903 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.895 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.902 total time=   0.7s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.891 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.876 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.899 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.883 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.895 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.876 total time=   0.1s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.876 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.891 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.891 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.891 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.872 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.876 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.903 total time=   0.5s
# [CV 3/5] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.880 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.891 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.880 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.884 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.895 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.898 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.906 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.902 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.895 total time=   0.5s
# [CV 2/5] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.888 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.887 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.898 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.906 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.891 total time=   0.8s
# [CV 2/5] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.891 total time=   0.7s
# [CV 3/5] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.887 total time=   0.9s
# [CV 4/5] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.906 total time=   0.6s
# [CV 5/5] END criterion=gini, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.902 total time=   0.8s
# [CV 1/5] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.888 total time=   0.3s
# [CV 2/5] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.891 total time=   0.3s
# [CV 3/5] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.891 total time=   0.2s
# [CV 4/5] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.902 total time=   0.2s
# [CV 5/5] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.891 total time=   0.2s
# [CV 1/5] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.895 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.910 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.883 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.891 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.891 total time=   0.5s
# [CV 1/5] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.880 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.906 total time=   0.6s
# [CV 3/5] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.883 total time=   0.5s
# [CV 4/5] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.895 total time=   0.4s
# [CV 5/5] END criterion=gini, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.891 total time=   0.6s
# [CV 1/5] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.891 total time=   0.2s
# [CV 2/5] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.888 total time=   0.1s
# [CV 3/5] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.887 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.891 total time=   0.1s
# [CV 5/5] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.865 total time=   0.4s
# [CV 1/5] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.876 total time=   0.4s
# [CV 2/5] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.903 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.883 total time=   0.3s
# [CV 4/5] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.898 total time=   0.3s
# [CV 5/5] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.880 total time=   0.3s
# [CV 1/5] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.884 total time=   0.6s
# [CV 2/5] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.895 total time=   0.4s
# [CV 3/5] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.868 total time=   0.4s
# [CV 4/5] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.895 total time=   0.5s
# [CV 5/5] END criterion=gini, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.872 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.880 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.884 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.883 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.898 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=100;, score=0.895 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.895 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.895 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.887 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.887 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=150;, score=0.895 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.880 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.891 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.883 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.883 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_split=3, n_estimators=200;, score=0.883 total time=   0.7s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.876 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.906 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.880 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.883 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=100;, score=0.883 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.880 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.884 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.883 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.880 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=150;, score=0.887 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.884 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.888 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.876 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.887 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_split=5, n_estimators=200;, score=0.887 total time=   0.6s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.876 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.895 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.872 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.880 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=100;, score=0.868 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.884 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.884 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.880 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.872 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=150;, score=0.865 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.869 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.876 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.868 total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.880 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=20, min_samples_split=8, n_estimators=200;, score=0.880 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.884 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.888 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.887 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.898 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=100;, score=0.902 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.888 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.876 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.895 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.910 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=150;, score=0.898 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.903 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.899 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.883 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.906 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=30, min_samples_split=3, n_estimators=200;, score=0.891 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.876 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.903 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.883 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.898 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=100;, score=0.887 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.895 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.888 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.895 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.906 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=150;, score=0.895 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.891 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.895 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.891 total time=   0.8s
# [CV 4/5] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.898 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=30, min_samples_split=5, n_estimators=200;, score=0.887 total time=   0.9s
# [CV 1/5] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.895 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.891 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.868 total time=   0.3s
# [CV 4/5] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.880 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=100;, score=0.861 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.880 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.906 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.880 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.887 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=150;, score=0.880 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.880 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.903 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.880 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.887 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=30, min_samples_split=8, n_estimators=200;, score=0.876 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.895 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.891 total time=   0.3s
# [CV 3/5] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.895 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.898 total time=   0.3s
# [CV 5/5] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=100;, score=0.887 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.880 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.891 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.895 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.895 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=150;, score=0.891 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.903 total time=   0.5s
# [CV 2/5] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.895 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.887 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.898 total time=   0.5s
# [CV 5/5] END criterion=entropy, max_depth=40, min_samples_split=3, n_estimators=200;, score=0.898 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.884 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.891 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.883 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.898 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=100;, score=0.880 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.888 total time=   0.4s
# [CV 2/5] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.899 total time=   0.5s
# [CV 3/5] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.880 total time=   0.5s
# [CV 4/5] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.895 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=150;, score=0.887 total time=   0.5s
# [CV 1/5] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.876 total time=   0.7s
# [CV 2/5] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.884 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.880 total time=   0.6s
# [CV 4/5] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.891 total time=   0.6s
# [CV 5/5] END criterion=entropy, max_depth=40, min_samples_split=5, n_estimators=200;, score=0.891 total time=   0.8s
# [CV 1/5] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.869 total time=   0.2s
# [CV 2/5] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.895 total time=   0.2s
# [CV 3/5] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.876 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.887 total time=   0.2s
# [CV 5/5] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=100;, score=0.872 total time=   0.3s
# [CV 1/5] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.888 total time=   0.3s
# [CV 2/5] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.895 total time=   0.4s
# [CV 3/5] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.880 total time=   0.4s
# [CV 4/5] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.883 total time=   0.4s
# [CV 5/5] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=150;, score=0.876 total time=   0.4s
# [CV 1/5] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.895 total time=   0.6s
# [CV 2/5] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.903 total time=   0.6s
# [CV 3/5] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.876 total time=   0.7s
# [CV 4/5] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.895 total time=   0.7s
# [CV 5/5] END criterion=entropy, max_depth=40, min_samples_split=8, n_estimators=200;, score=0.880 total time=   0.6s
# GridSearchCV(estimator=ExtraTreesClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [20, 30, 40],
#                          'min_samples_split': [3, 5, 8],
#                          'n_estimators': [100, 150, 200]},
#              verbose=5)

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 40,
#  'min_samples_split': 3,
#  'n_estimators': 100}

# %% [markdown]
# ## Deploying Final Model on the base of best Params

# %%
Final_mod = ExtraTreesClassifier(criterion='gini',n_estimators= 150, max_depth=40 ,min_samples_split= 3)
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\033[1m'+'Accuracy Score :'+'\033[0m\n', accuracy_score(Y_test, y_pred))
print('\n')
print('\033[1m'+'Confusion matrix of Extra Trees Classifier :'+'\033[0m \n',confusion_matrix(Y_test, y_pred))
print('\n')
print('\033[1m'+'Classification Report of Extra Trees Classifier'+'\033[0m \n',classification_report(Y_test, y_pred))
# Out:
# Accuracy Score :
#  0.9020979020979021
#
#
# Confusion matrix of Extra Trees Classifier :
#  [[72  0  0  0  0  0  1  2]
#  [ 6 46  6  2  2  1  1  1]
#  [ 0  1 62  0  0  2  0  1]
#  [ 1  7  4 61  0  1  1  2]
#  [ 0  0  0  0 78  0  0  0]
#  [ 0  0  0  0  0 63  0  0]
#  [ 2  3  0  0  0  0 64  2]
#  [ 2  1  0  0  0  0  4 70]]
#
#
# Classification Report of Extra Trees Classifier
#                precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91        75
#            1       0.79      0.71      0.75        65
#            2       0.86      0.94      0.90        66
#            3       0.97      0.79      0.87        77
#            4       0.97      1.00      0.99        78
#            5       0.94      1.00      0.97        63
#            6       0.90      0.90      0.90        71
#            7       0.90      0.91      0.90        77
#
#     accuracy                           0.90       572
#    macro avg       0.90      0.90      0.90       572
# weighted avg       0.90      0.90      0.90       572

# %%
y_prob = Final_mod.predict_proba(X_test)

macro_roc_auc_ovo = roc_auc_score(Y_test, y_prob, multi_class="ovo", average="macro")
weighted_roc_auc_ovo = roc_auc_score(Y_test, y_prob, multi_class="ovo", average="weighted")
macro_roc_auc_ovr = roc_auc_score(Y_test, y_prob, multi_class="ovr", average="macro")
weighted_roc_auc_ovr = roc_auc_score(Y_test, y_prob, multi_class="ovr", average="weighted")
print("One-vs-One ROC AUC scores:\n{:.6f} (macro),\n{:.6f} "
      "(weighted by prevalence)"
      .format(macro_roc_auc_ovo, weighted_roc_auc_ovo))
print("="*40)
print("One-vs-Rest ROC AUC scores:\n{:.6f} (macro),\n{:.6f} "
      "(weighted by prevalence)"
      .format(macro_roc_auc_ovr, weighted_roc_auc_ovr))
# Out:
# One-vs-One ROC AUC scores:
# 0.988679 (macro),
# 0.988773 (weighted by prevalence)
# ========================================
# One-vs-Rest ROC AUC scores:
# 0.988694 (macro),
# 0.988900 (weighted by prevalence)

# %% [markdown]
# ## Plotting ROC and comparing AUC for the final model

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
from sklearn.multiclass import OneVsRestClassifier

# %%
classifier = OneVsRestClassifier(Final_mod)
y_score = classifier.fit(X_train, Y_train).predict_proba(X_test)

#Binarize the output
Y_test_bin  = label_binarize(Y_test, classes=[0,1,2,3,4,5,6,7])
n_classes = 8

# Compute ROC curve and AUC for all the classes
false_positive_rate = dict()
true_positive_rate = dict()
roc_auc = dict()
for i in range(n_classes):
    false_positive_rate[i], true_positive_rate[i], _ = roc_curve(Y_test_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(false_positive_rate[i], true_positive_rate[i])
    
for i in range(n_classes):
    plt.plot(false_positive_rate[i], true_positive_rate[i], lw=2,
             label='ROC curve of class {0} (area = {1:0.2f})'
             ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([-0.05, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multiclassification data')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn import metrics
class_names = df.columns
metrics.plot_confusion_matrix(Final_mod, X_test, Y_test, cmap='mako')
plt.title('\t Confusion Matrix for Extra Trees Classifier \n')
plt.show()

# %%
# Saving the model as .pkl file
import joblib
joblib.dump(Final_mod,"powerplant_classification_Final")
# Out:
# ['powerplant_classification_Final']

# %% [markdown]
# # NOW Building Machine Learning Model  for Regression Algorithm

# %%
pip install xgboost
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  Ridge
from sklearn.linear_model import  Lasso

# %% [markdown]
# # Feature Engineering before proceeding

# %%
df2=df.copy()

# %%
df3=df2.copy()
Q1 = df3.quantile(0)
Q3= df3.quantile(0.85)
IQR = Q3 - Q1
print(IQR)
# Out:
# capacity_mw             720.000000
# latitude                 19.198860
# longitude                13.304440
# primary_fuel              6.000000
# other_fuel1               2.000000
# generation_gwh_2014    1856.927800
# generation_gwh_2015    2298.962020
# generation_gwh_2016    2435.205000
# generation_gwh_2017    2622.083625
# generation_gwh_2018    2688.268830
# Power_plant_age          29.000000
# dtype: float64

# %%
data = df3[~((df3 < (Q1 - 1.5 * IQR)) |(df3 > (Q3 + 1.5 * IQR))).any(axis=1)]
print(data.shape)
# Out:
# (813, 11)

# %%
skew = ['longitude','other_fuel1','generation_gwh_2018','generation_gwh_2014','generation_gwh_2015','generation_gwh_2016','generation_gwh_2017','Power_plant_age']
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method = 'yeo-johnson')
data[skew] = scaler.fit_transform(data[skew].values)
data[skew].head()
# Out:
#    longitude  other_fuel1  generation_gwh_2018  generation_gwh_2014  \
# 0  -0.897680     0.060858             0.098307             0.096542
# 1  -0.476753     0.060858             0.098307             0.096542
# 2  -2.407786     0.060858             0.098307             0.096542
# 3   2.167844     0.060858            -0.085888            -0.215837
# 5  -2.757337     0.060858             0.386376             0.602687
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# 0             0.098062             0.113532             0.131840
# 1             0.098062             0.113532             0.131840
# 2             0.098062             0.113532             0.131840
# 3             0.294230             0.323198            -0.087088
# 5             0.753205             0.677318             0.528644
#
#    Power_plant_age
# 0        -1.135038
# 1        -0.040224
# 2        -0.040224
# 3        -0.318991
# 5        -0.419165

# %%
# We will drop other fuel as result of poor correlation and lot of missing values
data.drop("other_fuel1",axis=1,inplace=True)
# Missing Value Imputation of latitude with mean
data['Power_plant_age'] = data['Power_plant_age'].fillna(data['Power_plant_age'].mean())

# %%
# Splitting data in target and dependent feature
X = data.drop(['capacity_mw'], axis =1)
Y = data['capacity_mw']

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
X_scale = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=557, test_size=.33)
print('Training feature matrix size:',X_train.shape)
print('Training target vector size:',Y_train.shape)
print('Test feature matrix size:',X_test.shape)
print('Test target vector size:',Y_test.shape)
# Out:
# Training feature matrix size: (544, 9)
# Training target vector size: (544,)
# Test feature matrix size: (269, 9)
# Test target vector size: (269,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
maxR2_score=0
maxRS=0
for i in range(1,200):
    X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=i, test_size=.33)
    lin_reg=LinearRegression()
    lin_reg.fit(X_train,Y_train)
    y_pred=lin_reg.predict(X_test)
    R2=r2_score(Y_test,y_pred)
    if R2>maxR2_score:
        maxR2_score=R2
        maxRS=i
print('Best R2 Score is', maxR2_score ,'on Random_state', maxRS)
# Out:
# Best R2 Score is 0.42889845952104744 on Random_state 131

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X_scale, Y, random_state=131, test_size=.3)
lin_reg=LinearRegression()
lin_reg.fit(X_train,Y_train)
lin_reg.score(X_train,Y_train)
y_pred=lin_reg.predict(X_test)
print('\033[1m'+'Predicted Wins:'+'\033[0m\n',y_pred)
print('\n')
print('\033[1m'+'Actual Wins:'+'\033[0m\n',Y_test)
# Out:
# Predicted Wins:
#  [ 9.28407617e+01  2.80890813e+02  2.22347982e+02  1.96425463e+02
#   4.47971091e+02  5.52968826e+02  1.01362277e+02  3.48835807e+01
#   1.19154287e+02  6.58202792e+01  2.12617496e+02  9.46062795e+01
#   2.75033518e+02  2.72354278e+02  6.62514041e+01  3.85675857e+02
#   2.60220745e+02  3.08170191e+02  4.79235962e+02  5.08962766e+02
#  -1.30058125e+02 -8.79094610e+01  9.20469630e+01  2.79762594e+02
#   5.80040532e+01  6.30284331e+02  2.29499106e+02  2.77586617e+02
#   6.52082477e+02  6.86136714e+01  5.45207284e+01  6.64705587e+01
#   6.62514041e+01  3.60325091e+02  4.25836187e+01  2.39681480e+02
#   6.48969215e+01  4.17662977e+01  1.53372280e+02  2.51014568e+02
#   3.06115345e+02 -1.44092971e+01  2.90460385e+02  6.72526338e+01
#   6.80621912e+02  2.92739006e+02 -2.97711750e+01  6.59782646e+01
#   5.76058806e+02  2.48090625e+02 -9.64644789e+01  4.44281260e+02
#  -3.00317357e+01  1.28413948e+01  9.82792604e+00  2.79269162e+02
#   1.19401575e+02  9.77370399e+01  1.45729525e+02  1.62108665e+01
#   2.33076852e+02  4.00033991e+01  7.87281784e+00  5.34646129e+02
#   6.51808051e+01  1.72701250e+02  2.59044356e+02  2.77589838e+02
#   9.40979823e+01  3.17737532e+02  2.91240188e+01  5.81198818e+02
#  -1.58355673e+01  9.35369942e+01  2.79098971e+02  2.58314884e+02
#   1.04300516e+02  7.26681360e+00  2.36084124e+02 -1.23895327e+02
#   4.29241294e+02  2.71695603e+02  2.45652947e+01  1.53682840e+02
#   4.94099291e+02  2.77476790e+02 -1.31923798e+02  1.75893167e+02
#   6.98662460e+01  1.29323275e+02  3.46665099e+02  2.53513626e+02
#   6.58276545e+01  2.76158142e+02  4.84335686e+02  2.58013685e+02
#   9.40492064e+01  6.74071509e+00  9.85775721e+00  4.82300052e+01
#   6.00813589e+01 -3.50225353e+01  6.62514041e+01  5.35226624e+01
#   2.81440844e+02  3.01525842e+02  1.78946780e+02  2.40742290e+02
#   2.40931795e+02  6.67859990e+01  3.88419809e+02  1.12496494e+02
#   4.96898669e+02  6.12591223e+02  9.60143813e+01  2.80110194e+02
#   1.75757597e+02  4.54016919e+02 -1.24217917e+01  1.96472115e+02
#   1.72701250e+02  1.60199474e+02  2.34672775e+02  6.69742474e+01
#   1.99863153e+02  4.69994666e+02  1.32062378e+02  3.14425959e+01
#   9.96714292e+01 -5.15609295e+01  2.77600957e+02  6.64797455e+01
#   1.42529616e+02  4.89050287e+01  8.41544606e+01  2.74825254e+02
#  -1.34341543e+01  3.17800402e+02  4.95650321e+01  6.62514041e+01
#   2.02597838e+02  3.75222739e+01  1.78201356e+02  5.30466965e+02
#   4.67740734e+01  8.66465832e+01 -4.72624187e+01  6.59094278e+01
#   1.13489831e+02  6.71118020e+01  1.01189756e+02  2.18552538e+02
#   6.00037849e+01  2.37787485e+02  2.62392555e+02 -6.26402021e-01
#   4.84429701e+02  2.68975524e+02  2.49047906e+02  1.45729525e+02
#   3.74101703e+02 -5.79888763e+01  4.40731239e+01  1.60054128e+02
#   1.53878022e+02  6.85914398e+00 -2.37280907e+01  1.35614385e+02
#   6.36244731e+01 -3.35102138e+00  2.47759184e+02  2.74820024e+02
#  -1.32766767e+01  9.97181672e+01 -7.31096713e+01  4.47313191e+02
#   1.04815806e+02  7.03831027e+02  4.73174621e+01  1.00271487e+02
#   1.15487285e+02  1.67498170e+02  2.32776284e+02  4.64377221e+02
#   6.35541057e+01  6.67200314e+01  2.50382402e+02  2.51427143e+02
#   4.04455802e+02 -7.16974713e+01  4.77843074e+01  3.90470863e+02
#   2.76540547e+02  5.53377915e+01  1.66262798e+02  2.23833286e+02
#   1.67212873e+01  7.15292854e+01  6.24395304e+01 -1.16739725e+01
#  -6.67031478e-01  4.00928298e+01  9.20469630e+01 -9.44479136e+01
#   1.34973447e+02  3.65201324e+02  1.49993971e+02 -1.10218038e+02
#   3.45425095e+02  1.05374715e+02  1.78750506e+02  2.81471547e+02
#  -3.78657313e+01  2.01762100e+02 -6.04854879e+01  8.91795610e+00
#   1.85946785e+02  4.72544587e+02  3.50951392e+01  2.10693268e+01
#   5.67871454e+01 -5.71402661e+01  1.50012391e+02  2.47886222e+02
#   2.64690584e+02  2.93165628e+02  2.89137826e+02 -5.38298718e+01
#   9.20325097e+01  3.20349409e+02  1.72782778e+02  5.12323880e+01
#   4.27624447e+02  1.65505721e+02  2.96410588e+02  2.23455630e+02
#   4.45268162e+02  9.36923189e+01  4.72191235e+01  1.30707517e+02
#   7.06638022e+01  2.73894900e+02  5.26421688e+01  6.72584576e+01]
#
#
# Actual Wins:
#  437      20.000
# 652      63.000
# 210     431.586
# 815      18.000
# 800    1000.000
#          ...
# 551       5.800
# 400      10.000
# 355      20.000
# 60       90.000
# 211       4.250
# Name: capacity_mw, Length: 244, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
print('\033[1m'+' Error :'+'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
from sklearn.metrics import r2_score
print('\033[1m'+' R2 Score :'+'\033[0m')
print(r2_score(Y_test,y_pred,multioutput='variance_weighted'))
# Out:
#  Error :
# Mean absolute error : 158.88335600237053
# Mean squared error : 50684.903919821416
# Root Mean Squared Error: 225.13308046535812
#
#
#  R2 Score :
# 0.4208059743031514

# %%
from xgboost import XGBRegressor
rf = RandomForestRegressor()
dtc = DecisionTreeRegressor()
adb=AdaBoostRegressor(learning_rate=0.1)
gradb=GradientBoostingRegressor()
rd=Ridge(alpha=0.01)
xgb=XGBRegressor()
model = [rf,rd,dtc,adb,gradb,xgb]

for m in model:
    m.fit(X_train,Y_train)
    m.score(X_train,Y_train)
    y_pred = m.predict(X_test)
    print('\n')                                        
    print('\033[1m'+' Error of ', m, ':' +'\033[0m')
    print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
    print('Mean squared error :', mean_squared_error(Y_test,y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
    print('\n')

    print('\033[1m'+' R2 Score :'+'\033[0m')
    print(r2_score(Y_test,y_pred)) 
    print('==============================================================================================================')
# Out:
#  Error of  RandomForestRegressor() :
# Mean absolute error : 79.43561947342275
# Mean squared error : 22210.509052304216
# Root Mean Squared Error: 149.03190615537406
#
#
#  R2 Score :
# 0.7461927880709751
# ==============================================================================================================
#
#
#  Error of  Ridge(alpha=0.01) :
# Mean absolute error : 158.88331455380344
# Mean squared error : 50684.75227259094
# Root Mean Squared Error: 225.1327436704642
#
#
#  R2 Score :
# 0.42080770722879823
# ==============================================================================================================
#
#
#  Error of  DecisionTreeRegressor() :
# Mean absolute error : 108.95557786885246
# Mean squared error : 46945.74855255294
# Root Mean Squared Error: 216.66967612601664
#
#
#  R2 Score :
# 0.4635346031923395
# ==============================================================================================================
#
#
#  Error of  AdaBoostRegressor(learning_rate=0.1) :
# Mean absolute error : 110.32878168051734
# Mean squared error : 29353.22883590268
# Root Mean Squared Error: 171.3278402242399
#
#
#  R2 Score :
# 0.6645704448101242
# ==============================================================================================================
#
#
#  Error of  GradientBoostingRegressor() :
# Mean absolute error : 90.65689214644509
# Mean squared error : 27543.869276029538
# Root Mean Squared Error: 165.96345765266986
#
#
#  R2 Score :
# 0.6852466258101668
# ==============================================================================================================
#
#
#  Error of  XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...) :
# Mean absolute error : 94.12094359934574
# Mean squared error : 31907.146566566204
# Root Mean Squared Error: 178.62571642002223
#
#
#  R2 Score :
# 0.6353859386293186
# ==============================================================================================================

# %%
# Cross Validation
model = [rf,rd,dtc,adb,gradb,xgb]

for m in model:
    score = cross_val_score(m, X_scale, Y, cv =5)
    print('\n')
    print('\033[1m'+'Cross Validation Score :',m,":"+'\033[0m\n')
    print("Mean CV Score :",score.mean())
    print('==============================================================================================================')
# Out:
# Cross Validation Score : RandomForestRegressor() :
#
# Mean CV Score : 0.7042172458010064
# ==============================================================================================================
#
#
# Cross Validation Score : Ridge(alpha=0.01) :
#
# Mean CV Score : 0.3013759173147911
# ==============================================================================================================
#
#
# Cross Validation Score : DecisionTreeRegressor() :
#
# Mean CV Score : 0.3891701492390309
# ==============================================================================================================
#
#
# Cross Validation Score : AdaBoostRegressor(learning_rate=0.1) :
#
# Mean CV Score : 0.6328382374830029
# ==============================================================================================================
#
#
# Cross Validation Score : GradientBoostingRegressor() :
#
# Mean CV Score : 0.686510623982305
# ==============================================================================================================
#
#
# Cross Validation Score : XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...) :
#
# Mean CV Score : 0.6482534458110097
# ==============================================================================================================

# %%
from sklearn.model_selection import GridSearchCV

# %%
#RandomForestRegressor
parameters = {'criterion':['mse', 'mae'],
             'max_features':['auto', 'sqrt', 'log2'],
             'n_estimators':[0,100,200,300,500],
             'max_depth':[20,30,40,60]}

# %%
GCV = GridSearchCV(RandomForestRegressor(),parameters,verbose =10)

# %%
GCV.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [CV 1/5; 1/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=0
# [CV 1/5; 1/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 2/5; 1/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=0
# [CV 2/5; 1/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 3/5; 1/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=0
# [CV 3/5; 1/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 4/5; 1/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=0
# [CV 4/5; 1/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 5/5; 1/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=0
# [CV 5/5; 1/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 1/5; 2/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=100
# [CV 1/5; 2/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=100;, score=0.668 total time=   0.3s
# [CV 2/5; 2/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=100
# [CV 2/5; 2/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=100;, score=0.529 total time=   0.3s
# [CV 3/5; 2/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=100
# [CV 3/5; 2/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=100;, score=0.705 total time=   0.3s
# [CV 4/5; 2/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=100
# [CV 4/5; 2/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=100;, score=0.564 total time=   0.2s
# [CV 5/5; 2/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=100
# [CV 5/5; 2/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=100;, score=0.610 total time=   0.2s
# [CV 1/5; 3/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=200
# [CV 1/5; 3/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=200;, score=0.657 total time=   0.8s
# [CV 2/5; 3/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=200
# [CV 2/5; 3/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=200;, score=0.543 total time=   0.6s
# [CV 3/5; 3/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=200
# [CV 3/5; 3/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=200;, score=0.726 total time=   0.6s
# [CV 4/5; 3/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=200
# [CV 4/5; 3/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=200;, score=0.552 total time=   0.6s
# [CV 5/5; 3/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=200
# [CV 5/5; 3/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=200;, score=0.630 total time=   0.6s
# [CV 1/5; 4/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=300
# [CV 1/5; 4/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=300;, score=0.662 total time=   1.0s
# [CV 2/5; 4/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=300
# [CV 2/5; 4/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=300;, score=0.536 total time=   0.9s
# [CV 3/5; 4/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=300
# [CV 3/5; 4/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=300;, score=0.739 total time=   1.0s
# [CV 4/5; 4/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=300
# [CV 4/5; 4/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=300;, score=0.542 total time=   1.1s
# [CV 5/5; 4/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=300
# [CV 5/5; 4/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=300;, score=0.622 total time=   1.1s
# [CV 1/5; 5/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=500
# [CV 1/5; 5/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=500;, score=0.675 total time=   1.7s
# [CV 2/5; 5/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=500
# [CV 2/5; 5/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=500;, score=0.545 total time=   1.8s
# [CV 3/5; 5/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=500
# [CV 3/5; 5/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=500;, score=0.719 total time=   1.6s
# [CV 4/5; 5/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=500
# [CV 4/5; 5/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=500;, score=0.553 total time=   1.8s
# [CV 5/5; 5/120] START criterion=mse, max_depth=20, max_features=auto, n_estimators=500
# [CV 5/5; 5/120] END criterion=mse, max_depth=20, max_features=auto, n_estimators=500;, score=0.619 total time=   1.8s
# [CV 1/5; 6/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=0
# [CV 1/5; 6/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 2/5; 6/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=0
# [CV 2/5; 6/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 3/5; 6/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=0
# [CV 3/5; 6/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 4/5; 6/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=0
# [CV 4/5; 6/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 5/5; 6/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=0
# [CV 5/5; 6/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 1/5; 7/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=100
# [CV 1/5; 7/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.678 total time=   0.2s
# [CV 2/5; 7/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=100
# [CV 2/5; 7/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.582 total time=   0.2s
# [CV 3/5; 7/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=100
# [CV 3/5; 7/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.762 total time=   0.2s
# [CV 4/5; 7/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=100
# [CV 4/5; 7/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.595 total time=   0.2s
# [CV 5/5; 7/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=100
# [CV 5/5; 7/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=100;, score=0.655 total time=   0.2s
# [CV 1/5; 8/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 1/5; 8/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.690 total time=   0.4s
# [CV 2/5; 8/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 2/5; 8/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.567 total time=   0.4s
# [CV 3/5; 8/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 3/5; 8/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.769 total time=   0.4s
# [CV 4/5; 8/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 4/5; 8/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.605 total time=   0.5s
# [CV 5/5; 8/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=200
# [CV 5/5; 8/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=200;, score=0.627 total time=   0.4s
# [CV 1/5; 9/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=300
# [CV 1/5; 9/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=300;, score=0.691 total time=   0.9s
# [CV 2/5; 9/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=300
# [CV 2/5; 9/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=300;, score=0.575 total time=   0.8s
# [CV 3/5; 9/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=300
# [CV 3/5; 9/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=300;, score=0.749 total time=   0.7s
# [CV 4/5; 9/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=300
# [CV 4/5; 9/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=300;, score=0.596 total time=   0.7s
# [CV 5/5; 9/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=300
# [CV 5/5; 9/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=300;, score=0.652 total time=   0.7s
# [CV 1/5; 10/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=500
# [CV 1/5; 10/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=500;, score=0.690 total time=   1.3s
# [CV 2/5; 10/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=500
# [CV 2/5; 10/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=500;, score=0.552 total time=   1.2s
# [CV 3/5; 10/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=500
# [CV 3/5; 10/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=500;, score=0.757 total time=   1.2s
# [CV 4/5; 10/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=500
# [CV 4/5; 10/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=500;, score=0.606 total time=   1.5s
# [CV 5/5; 10/120] START criterion=mse, max_depth=20, max_features=sqrt, n_estimators=500
# [CV 5/5; 10/120] END criterion=mse, max_depth=20, max_features=sqrt, n_estimators=500;, score=0.639 total time=   1.4s
# [CV 1/5; 11/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=0
# [CV 1/5; 11/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 2/5; 11/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=0
# [CV 2/5; 11/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 3/5; 11/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=0
# [CV 3/5; 11/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 4/5; 11/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=0
# [CV 4/5; 11/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 5/5; 11/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=0
# [CV 5/5; 11/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 1/5; 12/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=100
# [CV 1/5; 12/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=100;, score=0.659 total time=   0.2s
# [CV 2/5; 12/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=100
# [CV 2/5; 12/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=100;, score=0.571 total time=   0.2s
# [CV 3/5; 12/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=100
# [CV 3/5; 12/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=100;, score=0.769 total time=   0.2s
# [CV 4/5; 12/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=100
# [CV 4/5; 12/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=100;, score=0.598 total time=   0.2s
# [CV 5/5; 12/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=100
# [CV 5/5; 12/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=100;, score=0.651 total time=   0.2s
# [CV 1/5; 13/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=200
# [CV 1/5; 13/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=200;, score=0.689 total time=   0.5s
# [CV 2/5; 13/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=200
# [CV 2/5; 13/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=200;, score=0.552 total time=   0.5s
# [CV 3/5; 13/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=200
# [CV 3/5; 13/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=200;, score=0.756 total time=   0.4s
# [CV 4/5; 13/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=200
# [CV 4/5; 13/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=200;, score=0.619 total time=   0.5s
# [CV 5/5; 13/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=200
# [CV 5/5; 13/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=200;, score=0.645 total time=   0.4s
# [CV 1/5; 14/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=300
# [CV 1/5; 14/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=300;, score=0.677 total time=   0.8s
# [CV 2/5; 14/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=300
# [CV 2/5; 14/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=300;, score=0.550 total time=   1.0s
# [CV 3/5; 14/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=300
# [CV 3/5; 14/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=300;, score=0.755 total time=   0.8s
# [CV 4/5; 14/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=300
# [CV 4/5; 14/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=300;, score=0.594 total time=   0.7s
# [CV 5/5; 14/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=300
# [CV 5/5; 14/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=300;, score=0.623 total time=   0.7s
# [CV 1/5; 15/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=500
# [CV 1/5; 15/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=500;, score=0.687 total time=   1.4s
# [CV 2/5; 15/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=500
# [CV 2/5; 15/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=500;, score=0.563 total time=   1.4s
# [CV 3/5; 15/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=500
# [CV 3/5; 15/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=500;, score=0.752 total time=   1.4s
# [CV 4/5; 15/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=500
# [CV 4/5; 15/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=500;, score=0.597 total time=   1.3s
# [CV 5/5; 15/120] START criterion=mse, max_depth=20, max_features=log2, n_estimators=500
# [CV 5/5; 15/120] END criterion=mse, max_depth=20, max_features=log2, n_estimators=500;, score=0.647 total time=   1.6s
# [CV 1/5; 16/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=0
# [CV 1/5; 16/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 2/5; 16/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=0
# [CV 2/5; 16/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 3/5; 16/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=0
# [CV 3/5; 16/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 4/5; 16/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=0
# [CV 4/5; 16/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 5/5; 16/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=0
# [CV 5/5; 16/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 1/5; 17/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=100
# [CV 1/5; 17/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=100;, score=0.650 total time=   0.3s
# [CV 2/5; 17/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=100
# [CV 2/5; 17/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=100;, score=0.529 total time=   0.3s
# [CV 3/5; 17/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=100
# [CV 3/5; 17/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=100;, score=0.735 total time=   0.2s
# [CV 4/5; 17/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=100
# [CV 4/5; 17/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=100;, score=0.554 total time=   0.2s
# [CV 5/5; 17/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=100
# [CV 5/5; 17/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=100;, score=0.609 total time=   0.2s
# [CV 1/5; 18/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=200
# [CV 1/5; 18/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=200;, score=0.680 total time=   0.6s
# [CV 2/5; 18/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=200
# [CV 2/5; 18/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=200;, score=0.524 total time=   0.6s
# [CV 3/5; 18/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=200
# [CV 3/5; 18/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=200;, score=0.730 total time=   0.7s
# [CV 4/5; 18/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=200
# [CV 4/5; 18/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=200;, score=0.560 total time=   0.7s
# [CV 5/5; 18/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=200
# [CV 5/5; 18/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=200;, score=0.625 total time=   0.9s
# [CV 1/5; 19/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=300
# [CV 1/5; 19/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=300;, score=0.665 total time=   1.0s
# [CV 2/5; 19/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=300
# [CV 2/5; 19/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=300;, score=0.551 total time=   0.9s
# [CV 3/5; 19/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=300
# [CV 3/5; 19/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=300;, score=0.715 total time=   0.9s
# [CV 4/5; 19/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=300
# [CV 4/5; 19/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=300;, score=0.548 total time=   0.9s
# [CV 5/5; 19/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=300
# [CV 5/5; 19/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=300;, score=0.624 total time=   0.9s
# [CV 1/5; 20/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=500
# [CV 1/5; 20/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=500;, score=0.662 total time=   1.7s
# [CV 2/5; 20/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=500
# [CV 2/5; 20/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=500;, score=0.544 total time=   1.8s
# [CV 3/5; 20/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=500
# [CV 3/5; 20/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=500;, score=0.730 total time=   1.5s
# [CV 4/5; 20/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=500
# [CV 4/5; 20/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=500;, score=0.548 total time=   1.5s
# [CV 5/5; 20/120] START criterion=mse, max_depth=30, max_features=auto, n_estimators=500
# [CV 5/5; 20/120] END criterion=mse, max_depth=30, max_features=auto, n_estimators=500;, score=0.619 total time=   1.6s
# [CV 1/5; 21/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=0
# [CV 1/5; 21/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 2/5; 21/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=0
# [CV 2/5; 21/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 3/5; 21/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=0
# [CV 3/5; 21/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 4/5; 21/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=0
# [CV 4/5; 21/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 5/5; 21/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=0
# [CV 5/5; 21/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 1/5; 22/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=100
# [CV 1/5; 22/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=100;, score=0.697 total time=   0.2s
# [CV 2/5; 22/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=100
# [CV 2/5; 22/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=100;, score=0.576 total time=   0.2s
# [CV 3/5; 22/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=100
# [CV 3/5; 22/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=100;, score=0.745 total time=   0.2s
# [CV 4/5; 22/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=100
# [CV 4/5; 22/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=100;, score=0.593 total time=   0.2s
# [CV 5/5; 22/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=100
# [CV 5/5; 22/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=100;, score=0.656 total time=   0.2s
# [CV 1/5; 23/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 1/5; 23/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.693 total time=   0.5s
# [CV 2/5; 23/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 2/5; 23/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.561 total time=   0.5s
# [CV 3/5; 23/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 3/5; 23/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.751 total time=   0.5s
# [CV 4/5; 23/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 4/5; 23/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.618 total time=   0.4s
# [CV 5/5; 23/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=200
# [CV 5/5; 23/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=200;, score=0.639 total time=   0.4s
# [CV 1/5; 24/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=300
# [CV 1/5; 24/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=300;, score=0.691 total time=   0.7s
# [CV 2/5; 24/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=300
# [CV 2/5; 24/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=300;, score=0.566 total time=   0.7s
# [CV 3/5; 24/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=300
# [CV 3/5; 24/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=300;, score=0.756 total time=   0.7s
# [CV 4/5; 24/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=300
# [CV 4/5; 24/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=300;, score=0.615 total time=   0.7s
# [CV 5/5; 24/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=300
# [CV 5/5; 24/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=300;, score=0.646 total time=   0.9s
# [CV 1/5; 25/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=500
# [CV 1/5; 25/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=500;, score=0.688 total time=   1.5s
# [CV 2/5; 25/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=500
# [CV 2/5; 25/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=500;, score=0.555 total time=   1.5s
# [CV 3/5; 25/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=500
# [CV 3/5; 25/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=500;, score=0.752 total time=   1.6s
# [CV 4/5; 25/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=500
# [CV 4/5; 25/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=500;, score=0.606 total time=   1.4s
# [CV 5/5; 25/120] START criterion=mse, max_depth=30, max_features=sqrt, n_estimators=500
# [CV 5/5; 25/120] END criterion=mse, max_depth=30, max_features=sqrt, n_estimators=500;, score=0.642 total time=   1.3s
# [CV 1/5; 26/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=0
# [CV 1/5; 26/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 2/5; 26/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=0
# [CV 2/5; 26/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 3/5; 26/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=0
# [CV 3/5; 26/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 4/5; 26/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=0
# [CV 4/5; 26/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 5/5; 26/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=0
# [CV 5/5; 26/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 1/5; 27/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=100
# [CV 1/5; 27/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=100;, score=0.682 total time=   0.2s
# [CV 2/5; 27/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=100
# [CV 2/5; 27/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=100;, score=0.562 total time=   0.2s
# [CV 3/5; 27/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=100
# [CV 3/5; 27/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=100;, score=0.742 total time=   0.2s
# [CV 4/5; 27/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=100
# [CV 4/5; 27/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=100;, score=0.613 total time=   0.2s
# [CV 5/5; 27/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=100
# [CV 5/5; 27/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=100;, score=0.633 total time=   0.2s
# [CV 1/5; 28/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=200
# [CV 1/5; 28/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=200;, score=0.678 total time=   0.7s
# [CV 2/5; 28/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=200
# [CV 2/5; 28/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=200;, score=0.577 total time=   0.5s
# [CV 3/5; 28/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=200
# [CV 3/5; 28/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=200;, score=0.748 total time=   0.4s
# [CV 4/5; 28/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=200
# [CV 4/5; 28/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=200;, score=0.608 total time=   0.4s
# [CV 5/5; 28/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=200
# [CV 5/5; 28/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=200;, score=0.640 total time=   0.4s
# [CV 1/5; 29/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=300
# [CV 1/5; 29/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=300;, score=0.699 total time=   0.7s
# [CV 2/5; 29/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=300
# [CV 2/5; 29/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=300;, score=0.574 total time=   0.7s
# [CV 3/5; 29/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=300
# [CV 3/5; 29/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=300;, score=0.753 total time=   0.8s
# [CV 4/5; 29/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=300
# [CV 4/5; 29/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=300;, score=0.619 total time=   0.9s
# [CV 5/5; 29/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=300
# [CV 5/5; 29/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=300;, score=0.655 total time=   0.9s
# [CV 1/5; 30/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=500
# [CV 1/5; 30/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=500;, score=0.693 total time=   1.3s
# [CV 2/5; 30/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=500
# [CV 2/5; 30/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=500;, score=0.574 total time=   1.2s
# [CV 3/5; 30/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=500
# [CV 3/5; 30/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=500;, score=0.766 total time=   1.3s
# [CV 4/5; 30/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=500
# [CV 4/5; 30/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=500;, score=0.608 total time=   1.2s
# [CV 5/5; 30/120] START criterion=mse, max_depth=30, max_features=log2, n_estimators=500
# [CV 5/5; 30/120] END criterion=mse, max_depth=30, max_features=log2, n_estimators=500;, score=0.647 total time=   1.2s
# [CV 1/5; 31/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=0
# [CV 1/5; 31/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 2/5; 31/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=0
# [CV 2/5; 31/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 3/5; 31/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=0
# [CV 3/5; 31/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 4/5; 31/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=0
# [CV 4/5; 31/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 5/5; 31/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=0
# [CV 5/5; 31/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 1/5; 32/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=100
# [CV 1/5; 32/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=100;, score=0.666 total time=   0.2s
# [CV 2/5; 32/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=100
# [CV 2/5; 32/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=100;, score=0.526 total time=   0.3s
# [CV 3/5; 32/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=100
# [CV 3/5; 32/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=100;, score=0.710 total time=   0.2s
# [CV 4/5; 32/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=100
# [CV 4/5; 32/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=100;, score=0.551 total time=   0.2s
# [CV 5/5; 32/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=100
# [CV 5/5; 32/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=100;, score=0.610 total time=   0.3s
# [CV 1/5; 33/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=200
# [CV 1/5; 33/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=200;, score=0.668 total time=   0.8s
# [CV 2/5; 33/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=200
# [CV 2/5; 33/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=200;, score=0.544 total time=   0.6s
# [CV 3/5; 33/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=200
# [CV 3/5; 33/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=200;, score=0.722 total time=   0.6s
# [CV 4/5; 33/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=200
# [CV 4/5; 33/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=200;, score=0.546 total time=   0.6s
# [CV 5/5; 33/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=200
# [CV 5/5; 33/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=200;, score=0.632 total time=   0.6s
# [CV 1/5; 34/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=300
# [CV 1/5; 34/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=300;, score=0.673 total time=   0.9s
# [CV 2/5; 34/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=300
# [CV 2/5; 34/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=300;, score=0.530 total time=   0.9s
# [CV 3/5; 34/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=300
# [CV 3/5; 34/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=300;, score=0.725 total time=   0.9s
# [CV 4/5; 34/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=300
# [CV 4/5; 34/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=300;, score=0.554 total time=   0.9s
# [CV 5/5; 34/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=300
# [CV 5/5; 34/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=300;, score=0.634 total time=   0.9s
# [CV 1/5; 35/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=500
# [CV 1/5; 35/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=500;, score=0.671 total time=   1.5s
# [CV 2/5; 35/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=500
# [CV 2/5; 35/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=500;, score=0.550 total time=   1.7s
# [CV 3/5; 35/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=500
# [CV 3/5; 35/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=500;, score=0.729 total time=   1.6s
# [CV 4/5; 35/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=500
# [CV 4/5; 35/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=500;, score=0.549 total time=   1.6s
# [CV 5/5; 35/120] START criterion=mse, max_depth=40, max_features=auto, n_estimators=500
# [CV 5/5; 35/120] END criterion=mse, max_depth=40, max_features=auto, n_estimators=500;, score=0.620 total time=   1.8s
# [CV 1/5; 36/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=0
# [CV 1/5; 36/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 2/5; 36/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=0
# [CV 2/5; 36/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 3/5; 36/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=0
# [CV 3/5; 36/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 4/5; 36/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=0
# [CV 4/5; 36/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 5/5; 36/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=0
# [CV 5/5; 36/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 1/5; 37/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=100
# [CV 1/5; 37/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.678 total time=   0.2s
# [CV 2/5; 37/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=100
# [CV 2/5; 37/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.556 total time=   0.2s
# [CV 3/5; 37/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=100
# [CV 3/5; 37/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.767 total time=   0.2s
# [CV 4/5; 37/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=100
# [CV 4/5; 37/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.587 total time=   0.2s
# [CV 5/5; 37/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=100
# [CV 5/5; 37/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=100;, score=0.623 total time=   0.2s
# [CV 1/5; 38/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=200
# [CV 1/5; 38/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.689 total time=   0.4s
# [CV 2/5; 38/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=200
# [CV 2/5; 38/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.577 total time=   0.4s
# [CV 3/5; 38/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=200
# [CV 3/5; 38/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.735 total time=   0.4s
# [CV 4/5; 38/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=200
# [CV 4/5; 38/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.614 total time=   0.4s
# [CV 5/5; 38/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=200
# [CV 5/5; 38/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=200;, score=0.648 total time=   0.4s
# [CV 1/5; 39/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=300
# [CV 1/5; 39/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=300;, score=0.682 total time=   0.7s
# [CV 2/5; 39/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=300
# [CV 2/5; 39/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=300;, score=0.576 total time=   0.7s
# [CV 3/5; 39/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=300
# [CV 3/5; 39/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=300;, score=0.746 total time=   0.7s
# [CV 4/5; 39/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=300
# [CV 4/5; 39/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=300;, score=0.599 total time=   0.7s
# [CV 5/5; 39/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=300
# [CV 5/5; 39/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=300;, score=0.652 total time=   0.7s
# [CV 1/5; 40/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=500
# [CV 1/5; 40/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=500;, score=0.693 total time=   1.2s
# [CV 2/5; 40/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=500
# [CV 2/5; 40/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=500;, score=0.559 total time=   1.2s
# [CV 3/5; 40/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=500
# [CV 3/5; 40/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=500;, score=0.764 total time=   1.2s
# [CV 4/5; 40/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=500
# [CV 4/5; 40/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=500;, score=0.601 total time=   1.2s
# [CV 5/5; 40/120] START criterion=mse, max_depth=40, max_features=sqrt, n_estimators=500
# [CV 5/5; 40/120] END criterion=mse, max_depth=40, max_features=sqrt, n_estimators=500;, score=0.637 total time=   1.3s
# [CV 1/5; 41/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=0
# [CV 1/5; 41/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 2/5; 41/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=0
# [CV 2/5; 41/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 3/5; 41/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=0
# [CV 3/5; 41/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 4/5; 41/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=0
# [CV 4/5; 41/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 5/5; 41/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=0
# [CV 5/5; 41/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 1/5; 42/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=100
# [CV 1/5; 42/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=100;, score=0.697 total time=   0.2s
# [CV 2/5; 42/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=100
# [CV 2/5; 42/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=100;, score=0.544 total time=   0.2s
# [CV 3/5; 42/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=100
# [CV 3/5; 42/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=100;, score=0.774 total time=   0.2s
# [CV 4/5; 42/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=100
# [CV 4/5; 42/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=100;, score=0.598 total time=   0.2s
# [CV 5/5; 42/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=100
# [CV 5/5; 42/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=100;, score=0.656 total time=   0.2s
# [CV 1/5; 43/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=200
# [CV 1/5; 43/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=200;, score=0.690 total time=   0.4s
# [CV 2/5; 43/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=200
# [CV 2/5; 43/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=200;, score=0.562 total time=   0.4s
# [CV 3/5; 43/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=200
# [CV 3/5; 43/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=200;, score=0.764 total time=   0.4s
# [CV 4/5; 43/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=200
# [CV 4/5; 43/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=200;, score=0.601 total time=   0.4s
# [CV 5/5; 43/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=200
# [CV 5/5; 43/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=200;, score=0.643 total time=   0.4s
# [CV 1/5; 44/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=300
# [CV 1/5; 44/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=300;, score=0.691 total time=   0.7s
# [CV 2/5; 44/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=300
# [CV 2/5; 44/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=300;, score=0.576 total time=   0.7s
# [CV 3/5; 44/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=300
# [CV 3/5; 44/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=300;, score=0.762 total time=   0.7s
# [CV 4/5; 44/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=300
# [CV 4/5; 44/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=300;, score=0.603 total time=   0.7s
# [CV 5/5; 44/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=300
# [CV 5/5; 44/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=300;, score=0.648 total time=   0.7s
# [CV 1/5; 45/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=500
# [CV 1/5; 45/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=500;, score=0.690 total time=   1.2s
# [CV 2/5; 45/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=500
# [CV 2/5; 45/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=500;, score=0.577 total time=   1.2s
# [CV 3/5; 45/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=500
# [CV 3/5; 45/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=500;, score=0.756 total time=   1.2s
# [CV 4/5; 45/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=500
# [CV 4/5; 45/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=500;, score=0.606 total time=   1.2s
# [CV 5/5; 45/120] START criterion=mse, max_depth=40, max_features=log2, n_estimators=500
# [CV 5/5; 45/120] END criterion=mse, max_depth=40, max_features=log2, n_estimators=500;, score=0.645 total time=   1.2s
# [CV 1/5; 46/120] START criterion=mse, max_depth=60, max_features=auto, n_estimators=0
# [CV 1/5; 46/120] END criterion=mse, max_depth=60, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 2/5; 46/120] START criterion=mse, max_depth=60, max_features=auto, n_estimators=0
# [CV 2/5; 46/120] END criterion=mse, max_depth=60, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 3/5; 46/120] START criterion=mse, max_depth=60, max_features=auto, n_estimators=0
# [CV 3/5; 46/120] END criterion=mse, max_depth=60, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 4/5; 46/120] START criterion=mse, max_depth=60, max_features=auto, n_estimators=0
# [CV 4/5; 46/120] END criterion=mse, max_depth=60, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 5/5; 46/120] START criterion=mse, max_depth=60, max_features=auto, n_estimators=0
# [CV 5/5; 46/120] END criterion=mse, max_depth=60, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 1/5; 47/120] START criterion=mse, max_depth=60, max_features=auto, n_estimators=100
# [CV 1/5; 47/120] END criterion=mse, max_depth=60, max_features=auto, n_estimators=100;, score=0.679 total time=   0.3s
# [CV 2/5; 47/120] START criterion=mse, max_depth=60, max_features=auto, n_estimators=100
# [CV 2/5; 47/120] END criterion=mse, max_depth=60, max_features=auto, n_estimators=100;, score=0.532 total time=   0.2s
# [CV 3/5; 47/120] START criterion=mse, max_depth=60, max_features=auto, n_estimators=100
# [CV 3/5; 47/120] END criterion=mse, max_depth=60, max_features=auto, n_estimators=100;, score=0.745 total time=   0.3s
# [CV 4/5; 47/120] START criterion=mse, max_depth=60, max_features=auto, n_estimators=100
# ...
# [CV 1/5; 106/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=0
# [CV 1/5; 106/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 2/5; 106/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=0
# [CV 2/5; 106/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 3/5; 106/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=0
# [CV 3/5; 106/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 4/5; 106/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=0
# [CV 4/5; 106/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 5/5; 106/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=0
# [CV 5/5; 106/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=0;, score=nan total time=   0.0s
# [CV 1/5; 107/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=100
# [CV 1/5; 107/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=100;, score=0.657 total time=   1.4s
# [CV 2/5; 107/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=100
# [CV 2/5; 107/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=100;, score=0.532 total time=   1.7s
# [CV 3/5; 107/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=100
# [CV 3/5; 107/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=100;, score=0.753 total time=   1.4s
# [CV 4/5; 107/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=100
# [CV 4/5; 107/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=100;, score=0.581 total time=   1.4s
# [CV 5/5; 107/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=100
# [CV 5/5; 107/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=100;, score=0.631 total time=   1.4s
# [CV 1/5; 108/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=200
# [CV 1/5; 108/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=200;, score=0.661 total time=   3.2s
# [CV 2/5; 108/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=200
# [CV 2/5; 108/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=200;, score=0.547 total time=   2.8s
# [CV 3/5; 108/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=200
# [CV 3/5; 108/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=200;, score=0.744 total time=   2.8s
# [CV 4/5; 108/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=200
# [CV 4/5; 108/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=200;, score=0.583 total time=   3.0s
# [CV 5/5; 108/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=200
# [CV 5/5; 108/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=200;, score=0.603 total time=   2.9s
# [CV 1/5; 109/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=300
# [CV 1/5; 109/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=300;, score=0.661 total time=   4.4s
# [CV 2/5; 109/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=300
# [CV 2/5; 109/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=300;, score=0.547 total time=   4.2s
# [CV 3/5; 109/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=300
# [CV 3/5; 109/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=300;, score=0.736 total time=   4.5s
# [CV 4/5; 109/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=300
# [CV 4/5; 109/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=300;, score=0.575 total time=   4.4s
# [CV 5/5; 109/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=300
# [CV 5/5; 109/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=300;, score=0.627 total time=   4.3s
# [CV 1/5; 110/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=500
# [CV 1/5; 110/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=500;, score=0.665 total time=   7.8s
# [CV 2/5; 110/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=500
# [CV 2/5; 110/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=500;, score=0.559 total time=   7.2s
# [CV 3/5; 110/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=500
# [CV 3/5; 110/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=500;, score=0.738 total time=   7.5s
# [CV 4/5; 110/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=500
# [CV 4/5; 110/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=500;, score=0.584 total time=   7.2s
# [CV 5/5; 110/120] START criterion=mae, max_depth=60, max_features=auto, n_estimators=500
# [CV 5/5; 110/120] END criterion=mae, max_depth=60, max_features=auto, n_estimators=500;, score=0.608 total time=   8.2s
# [CV 1/5; 111/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=0
# [CV 1/5; 111/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 2/5; 111/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=0
# [CV 2/5; 111/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 3/5; 111/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=0
# [CV 3/5; 111/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 4/5; 111/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=0
# [CV 4/5; 111/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 5/5; 111/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=0
# [CV 5/5; 111/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=0;, score=nan total time=   0.0s
# [CV 1/5; 112/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=100
# [CV 1/5; 112/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=100;, score=0.663 total time=   0.7s
# [CV 2/5; 112/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=100
# [CV 2/5; 112/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=100;, score=0.569 total time=   0.8s
# [CV 3/5; 112/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=100
# [CV 3/5; 112/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=100;, score=0.736 total time=   0.7s
# [CV 4/5; 112/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=100
# [CV 4/5; 112/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=100;, score=0.614 total time=   0.8s
# [CV 5/5; 112/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=100
# [CV 5/5; 112/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=100;, score=0.629 total time=   0.8s
# [CV 1/5; 113/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=200
# [CV 1/5; 113/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=200;, score=0.673 total time=   1.7s
# [CV 2/5; 113/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=200
# [CV 2/5; 113/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=200;, score=0.559 total time=   1.5s
# [CV 3/5; 113/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=200
# [CV 3/5; 113/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=200;, score=0.757 total time=   1.7s
# [CV 4/5; 113/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=200
# [CV 4/5; 113/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=200;, score=0.607 total time=   1.7s
# [CV 5/5; 113/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=200
# [CV 5/5; 113/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=200;, score=0.639 total time=   1.8s
# [CV 1/5; 114/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=300
# [CV 1/5; 114/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=300;, score=0.673 total time=   2.7s
# [CV 2/5; 114/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=300
# [CV 2/5; 114/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=300;, score=0.563 total time=   2.6s
# [CV 3/5; 114/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=300
# [CV 3/5; 114/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=300;, score=0.742 total time=   2.6s
# [CV 4/5; 114/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=300
# [CV 4/5; 114/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=300;, score=0.605 total time=   2.6s
# [CV 5/5; 114/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=300
# [CV 5/5; 114/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=300;, score=0.629 total time=   2.7s
# [CV 1/5; 115/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=500
# [CV 1/5; 115/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=500;, score=0.681 total time=   4.5s
# [CV 2/5; 115/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=500
# [CV 2/5; 115/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=500;, score=0.558 total time=   3.8s
# [CV 3/5; 115/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=500
# [CV 3/5; 115/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=500;, score=0.756 total time=   4.0s
# [CV 4/5; 115/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=500
# [CV 4/5; 115/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=500;, score=0.617 total time=   4.1s
# [CV 5/5; 115/120] START criterion=mae, max_depth=60, max_features=sqrt, n_estimators=500
# [CV 5/5; 115/120] END criterion=mae, max_depth=60, max_features=sqrt, n_estimators=500;, score=0.649 total time=   4.4s
# [CV 1/5; 116/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=0
# [CV 1/5; 116/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 2/5; 116/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=0
# [CV 2/5; 116/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 3/5; 116/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=0
# [CV 3/5; 116/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 4/5; 116/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=0
# [CV 4/5; 116/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 5/5; 116/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=0
# [CV 5/5; 116/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=0;, score=nan total time=   0.0s
# [CV 1/5; 117/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=100
# [CV 1/5; 117/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=100;, score=0.691 total time=   0.8s
# [CV 2/5; 117/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=100
# [CV 2/5; 117/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=100;, score=0.546 total time=   0.8s
# [CV 3/5; 117/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=100
# [CV 3/5; 117/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=100;, score=0.732 total time=   0.7s
# [CV 4/5; 117/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=100
# [CV 4/5; 117/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=100;, score=0.617 total time=   0.7s
# [CV 5/5; 117/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=100
# [CV 5/5; 117/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=100;, score=0.617 total time=   0.7s
# [CV 1/5; 118/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=200
# [CV 1/5; 118/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=200;, score=0.690 total time=   1.5s
# [CV 2/5; 118/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=200
# [CV 2/5; 118/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=200;, score=0.555 total time=   1.5s
# [CV 3/5; 118/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=200
# [CV 3/5; 118/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=200;, score=0.762 total time=   1.5s
# [CV 4/5; 118/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=200
# [CV 4/5; 118/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=200;, score=0.603 total time=   1.5s
# [CV 5/5; 118/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=200
# [CV 5/5; 118/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=200;, score=0.648 total time=   1.6s
# [CV 1/5; 119/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=300
# [CV 1/5; 119/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=300;, score=0.673 total time=   2.9s
# [CV 2/5; 119/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=300
# [CV 2/5; 119/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=300;, score=0.555 total time=   2.6s
# [CV 3/5; 119/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=300
# [CV 3/5; 119/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=300;, score=0.740 total time=   2.4s
# [CV 4/5; 119/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=300
# [CV 4/5; 119/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=300;, score=0.607 total time=   2.5s
# [CV 5/5; 119/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=300
# [CV 5/5; 119/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=300;, score=0.644 total time=   2.6s
# [CV 1/5; 120/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=500
# [CV 1/5; 120/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=500;, score=0.675 total time=   4.3s
# [CV 2/5; 120/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=500
# [CV 2/5; 120/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=500;, score=0.547 total time=   4.6s
# [CV 3/5; 120/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=500
# [CV 3/5; 120/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=500;, score=0.742 total time=   4.2s
# [CV 4/5; 120/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=500
# [CV 4/5; 120/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=500;, score=0.619 total time=   4.2s
# [CV 5/5; 120/120] START criterion=mae, max_depth=60, max_features=log2, n_estimators=500
# [CV 5/5; 120/120] END criterion=mae, max_depth=60, max_features=log2, n_estimators=500;, score=0.654 total time=   4.3s
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['mse', 'mae'],
#                          'max_depth': [20, 30, 40, 60],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [0, 100, 200, 300, 500]},
#              verbose=10)

# %%
GCV.best_params_
# Out:
# {'criterion': 'mse',
#  'max_depth': 30,
#  'max_features': 'log2',
#  'n_estimators': 300}

# %%
from sklearn.ensemble import RandomForestRegressor
Final_mod =  RandomForestRegressor(n_estimators=300,criterion = 'mse', max_features = 'log2',max_depth30)
Final_mod.fit(X_train,Y_train)
y_pred=Final_mod.predict(X_test)
print('\n')                                        
print('\033[1m'+' Error in Final Model :' +'\033[0m')
print('Mean absolute error :', mean_absolute_error(Y_test,y_pred))
print('Mean squared error :', mean_squared_error(Y_test,y_pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(Y_test,y_pred)))
print('\n')
print('\033[1m'+' R2 Score of Final Model :'+'\033[0m')
print(r2_score(Y_test,y_pred)) 
print('\n')
# Out:
#  Error in Final Model :
# Mean absolute error : 78.0394756830601
# Mean squared error : 20744.412251779282
# Root Mean Squared Error: 144.02920624574477
#
#
#  R2 Score of Final Model :
# 0.7629463861304799

# %%
import joblib
joblib.dump(Final_mod,"Global_Power_Plant_capacity_mw.pkl")
# Out:
# ['Global_Power_Plant_capacity_mw.pkl']

# %%
plt.figure(figsize=(12,7))
y_pred=Final_mod.predict(X_test)
sns.swarmplot(Y_test.round(2), y_pred)
print('\033[1m'+' True Values Vs Predicted Value plot :' +'\033[0m')
plt.xlabel('True Values' , fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.tight_layout()
# Out:
#  True Values Vs Predicted Value plot :

# %% [markdown]
# ## Summary of Report

# %% [markdown]
# **1. I have imported necessary liabries like pandas, numpy , matplotlib to load the dataset and to check some stastical features.**
#
# **2. After loading data set I have checked shape of dataset, data types from which we will able to decide which is our target variable and which features affecting the target features.**
#
# **3. Missing value checked, and missing value filled by using median function, also we have droped some cloumns which having are not affecting to our target variable.**
#
# **4. after finding the data types we have distribute the dataset into two features 1. categorical and 2. numerical features, so it helps us to further pre processing on data set.**

# %% [markdown]
# **5. after this we have done exploratives data analysis by using various plots(like pie charts, crosstrab, barchart, scatter plot, volin plot etc) base on our target variable /feature i.e income**
#
# **6. Now we have done the feature engineering on dataset by using label encoding.**
#
# **7. after that check the correlation of various feature with target feature and non correlated features we have drop in further steps.**
#
# **8.after checking malticolinearity we found that its below 10 i.e permissible/ acceptable so we have not drop any features in multicolinearlity.**
#
# **9. Also we have done the data balacing using SMOTE oversampling feature for classification Problem**
#
# **10. afterwards implemented various machine learning model for classification and regression algorithm where taken the sampling ratio as 70: 30.**
#
# **11. Indentified the final model  base on highest accuracy, F1 score in classification alogrithm and for regression algorithm we have cosidered R2score.
# **12. Afterwards deployed hyper parameter tunning on best model using gridsearchCV.**
#
# **13. Afterwards we have save the final model and plotted the AOC and Roc plot on final model for classification Algorithm.**
#
#
# **saved the final model using joblib method in pkl file.**
